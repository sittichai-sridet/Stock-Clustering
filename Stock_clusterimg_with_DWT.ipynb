# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy import pi
from scipy.fftpack import fft
from scipy import stats
import pywt
import matplotlib.gridspec as gridspec
from itertools import combinations 
import sys

# %%
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.metrics import make_scorer
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score
from sklearn.preprocessing import StandardScaler

# %%
# !pip install pandas_datareader
from pandas_datareader import data as pdr
from tqdm import tqdm,trange
stock_list = ['ADVANC','AEONTS','AMATA','AOT','AP','AWC','BANPU','BBL','BCH','BCP',
            'BCPG','BDMS','BEC','BEM','BGC','BGRIM','BH','BJC','BPP','BTS',
            'CBG','CENTEL','CHG','CK','CKP','COM7','CPALL','CPF','CPN',
            'DELTA','DTAC','EA','EGCO','EPG','ERW','ESSO','GFPT','GLOBAL','GPSC',
            'GULF','GUNKUL','HANA','HMPRO','INTUCH','IRPC','IVL','JAS','JMT','KBANK',
            'KCE','KKP','KTB','KTC','LH','MAJOR','MBK','MEGA','MINT','MTC',
            'ORI','OSP','PLANB','PRM','PSH','PSL','PTG','PTT','PTTEP','PTTGC',
            'QH','RATCH','RS','SAWAD','SCB','SCC','SGP','SPALI','SPRC','STA',
            'STEC','STPI','SUPER','TASCO','TCAP','THAI','THANI','THG','TISCO','TKN',
            'TMB','TOA','TOP','TPIPP','TQM','TRUE','TTW','TU','VGI','WHA' ]
stock_data = []
stock_name = []
for quote in tqdm(stock_list):
    try:
        data = pdr.get_data_yahoo(f'{quote}.BK', start='2016-01-01', end='2019-12-31')
        stock_data.append(data)
        stock_name.append(quote)
        #data.to_csv('/content/drive/My Drive/paper IS/code stock/{:}.csv'.format(quote))
    except:
        print("Error:", sys.exc_info()[0])
        print("Description:", sys.exc_info()[1])
# Out:
# Requirement already satisfied: pandas_datareader in /usr/local/lib/python3.6/dist-packages (0.8.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.6/dist-packages (from pandas_datareader) (4.2.6)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from pandas_datareader) (2.23.0)
# Requirement already satisfied: pandas>=0.21 in /usr/local/lib/python3.6/dist-packages (from pandas_datareader) (1.0.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.3.0->pandas_datareader) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.3.0->pandas_datareader) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.3.0->pandas_datareader) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.3.0->pandas_datareader) (3.0.4)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.21->pandas_datareader) (1.18.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.21->pandas_datareader) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.21->pandas_datareader) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas>=0.21->pandas_datareader) (1.15.0)
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal
# 100%|██████████| 99/99 [00:41<00:00,  2.40it/s]

# %%
temp = []

for s_data in stock_data:
    #print(s_data)
    s_data['daily_return'] = s_data[['Close']].rolling(window=2).apply(lambda x:  x[1] / x[0] if x[0] != x[1] else 0 )
    s_data = s_data.iloc[1:, :]
    temp.append(s_data)

stock_data = temp

# %%
mode_lenght = stats.mode([data.shape[0] for data in stock_data])[0][0]
stock_data_filtered = []
stock_list_filtered = [] 

for i in range(len(stock_list)): 
    if stock_data[i].shape[0] == mode_lenght:
        stock_data_filtered.append(stock_data[i])
        stock_list_filtered.append(stock_list[i])

# %%
def reshape_two_dim(np_array): 
    return np_array.reshape([1, 1, np_array.shape[0]])

def create_wavelet_row(data, waveletname, level):
    result = []
    first_coeff = []

    for i in range(level):
        
        (data, coeff_d) = pywt.dwt(data, waveletname) 
        #reconstructed_signal = pywt.idwt(cA1, cD1, 'db2', 'smooth')
        
        if i == 0:
            first_coeff = list(coeff_d)
        result += list(data)

    result += first_coeff

    return result

# %%
def create_wavelet(waveletname, level):
    # windows parameter
    max_data_lenght = max_lenght
    window_lenght = 90 
    window_preiod = 7
    window_ship = window_lenght - window_preiod

    # calculate dimension 
    temp = window_lenght
    first_dim = 0
    dim = 0
    for i in range(level): 
        temp = (temp+1)//2
        if i == 0: 
            first_dim = temp
        dim += temp 
    dim += first_dim 

    global stock_data_filtered
    windows_objs = []

    max_index = max_data_lenght // (window_ship) * (window_ship)
    # index_end = data_lenght 

    for index in range(0, max_index, window_ship): 
        index_start = - index - window_lenght
        index_end = - index

        wavelet_table = []

        for data_with_columns in stock_data_filtered: 
            if data_with_columns.shape[0] < -index_start: 
                continue
            data = data_with_columns['daily_return'][index_start:] if index == 0 else data_with_columns['daily_return'][index_start:index_end]
            wavelet_row = create_wavelet_row(data, waveletname, level) 
            wavelet_table += [wavelet_row]
            
        windows_obj = {} 

        for cal_score_obj in cal_scores:
            labels, score = k_mean(wavelet_table, cal_score_obj)

            windows_obj[cal_score_obj['name']] = { 
                'wavelet': wavelet_table, 
                'labels': labels,
                'score': score
            }

        windows_objs.append(windows_obj)

    # while index_start >= 0:
    #     wavelet_table = []

    #     for data_with_columns in stock_data_filtered: 
    #         data_len = data_with_columns.shape[0]
    #         if data_len < 
    #         data = data_with_columns['Adj Close'][index_start:index_end]
    #         wavelet_row = create_wavelet_row(data, waveletname, level) 
    #         wavelet_table += [wavelet_row]

    #     labels, score = k_mean(wavelet_table)

    #     windows_obj = { 
    #         'wavelet': wavelet_table, 
    #         'labels': labels,
    #         'score': score
    #     }

    #     windows_objs.append(windows_obj)

    #     # update index 
    #     index_start -= window_lenght - window_preiod
    #     index_end -= window_lenght - window_preiod
    
    windows_objs = windows_objs[::-1]

    wavelet_obj = {
        'windows': windows_objs,
    }
    for cal_score_obj in cal_scores: 
        score_name = cal_score_obj['name']
        wavelet_obj['avg_'+score_name] = sum([window[score_name]['score'] for window in windows_objs]) / len(windows_objs)

    return wavelet_obj

# %%
cal_scores = [{
      'name': 'silhouette_score',
      'fn': silhouette_score,
      'optimize': max
  },{
      'name': 'davies_bouldin_score',
      'fn': davies_bouldin_score,
      'optimize': min
  },{
      'name': 'calinski_harabasz_score',
      'fn': calinski_harabasz_score,
      'optimize': max
  }]

def find_k(X, cal_score_obj):
    score_fn = cal_score_obj['fn']
    score_optimize = cal_score_obj['optimize']
    range_n_clusters = np.arange(3,20)
    scores = []
    cluster_center = {}
    for n_clusters in range_n_clusters:
        

        # def euc_dist(X, Y = None, Y_norm_squared = None, squared = False):
        #     return pairwise_distances(X, metric = 'cosine', n_jobs = -1)
        # #     #return np.arccos(cosine_similarity(X, Y))/np.pi

        # KMeans.euclidean_distances = euc_dist
        # #print('euclidean_distances')
        clusterer = KMeans(n_clusters=n_clusters, init='k-means++',max_iter=1000)
        clusterer = clusterer.fit(X)
        scores.append(score_fn(X, clusterer.predict(X)))
        cluster_center.update({'{}'.format(n_clusters):clusterer.cluster_centers_})
    return range_n_clusters[scores.index(score_optimize(scores))] 

def k_mean(X, cal_score_obj):
    global stock_list_filtered 
    score_fn = cal_score_obj['fn']
    X = StandardScaler().fit_transform(X)
    k = find_k(X, cal_score_obj)

    # def euc_dist(X, Y = None, Y_norm_squared = None, squared = False):
    #     return pairwise_distances(X, metric = 'correlation', n_jobs = -1)
    # #     #return np.arccos(cosine_similarity(X, Y))/np.pi

    # KMeans.euclidean_distances = euc_dist

    clusters = KMeans(n_clusters = k, init='k-means++',max_iter=1000)
    clusters.fit(X)

    labels = [ [] for i in range(k)]
    for i, label in enumerate(clusters.labels_): 
        labels[label] += [stock_list_filtered[i]]
    return labels, score_fn(X, clusters.labels_)

# %%
list_wt = ['bior1.1', 'bior2.2', 'bior2.4', 
 'bior3.1', 'bior3.9', 'bior4.4', 'bior5.5', 
 'bior6.8', 'coif1', 'coif2', 'coif3', 'coif4',
 'coif9', 'coif10', 'coif15', 'coif16', 'coif17',
 'db1', 'db2', 'db3', 'db4', 
  'db26', 'db27', 'db28',  'db34', 'db35', 'db36', 'db37'
 , 'db38', 'dmey', 'haar', 'rbio1.1', 'rbio2.2'
 , 'rbio3.5', 'rbio3.7', 'rbio3.9', 'rbio4.4', 'rbio5.5', 'rbio6.8', 'sym2', 'sym3',
 'sym16', 'sym17', 'sym18', 'sym19', 'sym20']

# %%
wavelet_parameter= ['haar', 'db1', 'db2', 'db3', 'db4','db26', 'db27', 'db28',  'db34', 'db35', 'db36', 'db37', 'db38']
max3rank = ['db38','coif17',  'dmey']
level = 2

wavelet_names = list_wt
wavelet_table = {}

for wavelet_name in wavelet_names: 
    wavelet_table[wavelet_name] = create_wavelet(wavelet_name, level)

# %%
for wavelet_name in wavelet_names: 
    score_display = ''
    for cal_score_obj in cal_scores: 
        score_name = cal_score_obj['name']
        avg_score = wavelet_table[wavelet_name]['avg_' + score_name]
        score_display += '\t {:}: {:8.6f}'.format(score_name, avg_score)
    print('wavelet: {:7} {:}'.format(wavelet_name, score_display))
# Out:
# wavelet: bior1.1 	 silhouette_score: 0.040843	 davies_bouldin_score: 1.999535	 calinski_harabasz_score: 3.250712
# wavelet: bior2.2 	 silhouette_score: 0.046083	 davies_bouldin_score: 1.979260	 calinski_harabasz_score: 2.828569
# wavelet: bior2.4 	 silhouette_score: 0.037007	 davies_bouldin_score: 1.880005	 calinski_harabasz_score: 2.968414
# wavelet: bior3.1 	 silhouette_score: 0.019370	 davies_bouldin_score: 2.016935	 calinski_harabasz_score: 2.753075
# wavelet: bior3.9 	 silhouette_score: 0.027938	 davies_bouldin_score: 2.006092	 calinski_harabasz_score: 3.109314
# wavelet: bior4.4 	 silhouette_score: 0.044743	 davies_bouldin_score: 1.927399	 calinski_harabasz_score: 3.629115
# wavelet: bior5.5 	 silhouette_score: 0.045475	 davies_bouldin_score: 1.887704	 calinski_harabasz_score: 4.438686
# wavelet: bior6.8 	 silhouette_score: 0.040143	 davies_bouldin_score: 1.966964	 calinski_harabasz_score: 3.753510
# wavelet: coif1   	 silhouette_score: 0.045871	 davies_bouldin_score: 1.906575	 calinski_harabasz_score: 3.334618
# wavelet: coif2   	 silhouette_score: 0.041543	 davies_bouldin_score: 1.847791	 calinski_harabasz_score: 3.802529
# wavelet: coif3   	 silhouette_score: 0.038242	 davies_bouldin_score: 1.834967	 calinski_harabasz_score: 3.893289
# wavelet: coif4   	 silhouette_score: 0.041749	 davies_bouldin_score: 1.813629	 calinski_harabasz_score: 3.942787
# wavelet: coif9   	 silhouette_score: 0.047642	 davies_bouldin_score: 1.945326	 calinski_harabasz_score: 3.994817
# wavelet: coif10  	 silhouette_score: 0.029744	 davies_bouldin_score: 2.005567	 calinski_harabasz_score: 3.882707
# wavelet: coif15  	 silhouette_score: 0.044743	 davies_bouldin_score: 1.873556	 calinski_harabasz_score: 3.797866
# wavelet: coif16  	 silhouette_score: 0.042198	 davies_bouldin_score: 1.932640	 calinski_harabasz_score: 3.909304
# wavelet: coif17  	 silhouette_score: 0.048379	 davies_bouldin_score: 1.855597	 calinski_harabasz_score: 4.027437
# wavelet: db1     	 silhouette_score: 0.042129	 davies_bouldin_score: 1.939207	 calinski_harabasz_score: 3.240516
# wavelet: db2     	 silhouette_score: 0.047219	 davies_bouldin_score: 1.963354	 calinski_harabasz_score: 3.330954
# wavelet: db3     	 silhouette_score: 0.052962	 davies_bouldin_score: 2.067543	 calinski_harabasz_score: 3.410141
# wavelet: db4     	 silhouette_score: 0.043790	 davies_bouldin_score: 1.890315	 calinski_harabasz_score: 3.548632
# wavelet: db26    	 silhouette_score: 0.036752	 davies_bouldin_score: 1.896887	 calinski_harabasz_score: 4.035068
# wavelet: db27    	 silhouette_score: 0.042890	 davies_bouldin_score: 1.861122	 calinski_harabasz_score: 3.940406
# wavelet: db28    	 silhouette_score: 0.036296	 davies_bouldin_score: 1.955954	 calinski_harabasz_score: 4.012523
# wavelet: db34    	 silhouette_score: 0.040376	 davies_bouldin_score: 1.908727	 calinski_harabasz_score: 4.000763
# wavelet: db35    	 silhouette_score: 0.052987	 davies_bouldin_score: 1.985521	 calinski_harabasz_score: 3.940102
# wavelet: db36    	 silhouette_score: 0.033213	 davies_bouldin_score: 1.976398	 calinski_harabasz_score: 3.905510
# wavelet: db37    	 silhouette_score: 0.059056	 davies_bouldin_score: 1.837906	 calinski_harabasz_score: 3.857084
# wavelet: db38    	 silhouette_score: 0.050885	 davies_bouldin_score: 1.870897	 calinski_harabasz_score: 3.925770
# wavelet: dmey    	 silhouette_score: 0.025844	 davies_bouldin_score: 1.965852	 calinski_harabasz_score: 3.764967
# wavelet: haar    	 silhouette_score: 0.046140	 davies_bouldin_score: 2.063020	 calinski_harabasz_score: 3.292267
# wavelet: rbio1.1 	 silhouette_score: 0.048064	 davies_bouldin_score: 2.046018	 calinski_harabasz_score: 3.232870
# wavelet: rbio2.2 	 silhouette_score: 0.033663	 davies_bouldin_score: 1.899943	 calinski_harabasz_score: 4.039147
# wavelet: rbio3.5 	 silhouette_score: 0.047504	 davies_bouldin_score: 1.917935	 calinski_harabasz_score: 5.026757
# wavelet: rbio3.7 	 silhouette_score: 0.064156	 davies_bouldin_score: 1.888658	 calinski_harabasz_score: 5.300726
# wavelet: rbio3.9 	 silhouette_score: 0.048129	 davies_bouldin_score: 1.891516	 calinski_harabasz_score: 5.455446
# wavelet: rbio4.4 	 silhouette_score: 0.046377	 davies_bouldin_score: 1.786146	 calinski_harabasz_score: 3.744228
# wavelet: rbio5.5 	 silhouette_score: 0.033434	 davies_bouldin_score: 1.896471	 calinski_harabasz_score: 3.356019
# wavelet: rbio6.8 	 silhouette_score: 0.048037	 davies_bouldin_score: 1.896962	 calinski_harabasz_score: 4.009292
# wavelet: sym2    	 silhouette_score: 0.039912	 davies_bouldin_score: 2.000413	 calinski_harabasz_score: 3.259716
# wavelet: sym3    	 silhouette_score: 0.030762	 davies_bouldin_score: 2.050527	 calinski_harabasz_score: 3.370151
# wavelet: sym16   	 silhouette_score: 0.057680	 davies_bouldin_score: 1.908826	 calinski_harabasz_score: 3.954451
# wavelet: sym17   	 silhouette_score: 0.040436	 davies_bouldin_score: 1.848950	 calinski_harabasz_score: 4.035834
# wavelet: sym18   	 silhouette_score: 0.050149	 davies_bouldin_score: 1.903614	 calinski_harabasz_score: 3.939543
# wavelet: sym19   	 silhouette_score: 0.046040	 davies_bouldin_score: 1.876081	 calinski_harabasz_score: 3.961178
# wavelet: sym20   	 silhouette_score: 0.049297	 davies_bouldin_score: 1.868615	 calinski_harabasz_score: 3.928086

# %%
# # correlation
# wavelet: db38    	 silhouette_score: 0.718954	 davies_bouldin_score: 0.554812	 calinski_harabasz_score: 133.693315
# wavelet: coif17  	 silhouette_score: 0.721539	 davies_bouldin_score: 0.526273	 calinski_harabasz_score: 139.995372
# wavelet: dmey    	 silhouette_score: 0.719515	 davies_bouldin_score: 0.541662	 calinski_harabasz_score: 129.814934

# # cosine
# wavelet: db38    	 silhouette_score: 0.717627	 davies_bouldin_score: 0.535833	 calinski_harabasz_score: 133.702446
# wavelet: coif17  	 silhouette_score: 0.720327	 davies_bouldin_score: 0.520331	 calinski_harabasz_score: 140.441201
# wavelet: dmey    	 silhouette_score: 0.720794	 davies_bouldin_score: 0.539038	 calinski_harabasz_score: 130.122441

# # Eucidean
# wavelet: db38    	 silhouette_score: 0.718954	 davies_bouldin_score: 0.537615	 calinski_harabasz_score: 133.701637
# wavelet: coif17  	 silhouette_score: 0.722503	 davies_bouldin_score: 0.519529	 calinski_harabasz_score: 140.691314
# wavelet: dmey    	 silhouette_score: 0.720588	 davies_bouldin_score: 0.541662	 calinski_harabasz_score: 130.049676

# %%
# for cal_score_obj in cal_scores:
#     score_name = cal_score_obj['name']
#     print('='*80)
#     print(score_name)
#     print('='*80)
#     for wavelet_name in wavelet_names:  
#         print('-'*50)
#         print(wavelet_name)
#         print('-'*50)
#         for window in wavelet_table[wavelet_name]['windows']: 
#             print(window[score_name]['score'])

# %%
for cal_score_obj in cal_scores:
    score_name = cal_score_obj['name']
    print('*'*50)
    print(score_name)
    for wavelet_name in wavelet_names:
        windows = wavelet_table[wavelet_name]['windows']
        avg_score = wavelet_table[wavelet_name]['avg_'+score_name] 
        print('='*50)
        print('wavelet: {:10} {:}: {:}'.format(wavelet_name, score_name, avg_score))
        for i, window in enumerate(windows): 
            window = window[score_name]
            print('-'*50)
            print('window {:}:'.format(i+1))
            for j, label in enumerate(window['labels']): 
                print('custer {:} have {:} stocks : {:}'.format(j+1, len(label), label))
            print('score of window: {:}.'.format(window['score']))
        print('\n\n\n')
# Out:
# Streaming output truncated to the last 5000 lines.
# custer 10 have 2 stocks : ['QH', 'SUPER']
# custer 11 have 5 stocks : ['ERW', 'GUNKUL', 'RATCH', 'STEC', 'THAI']
# custer 12 have 1 stocks : ['SPRC']
# custer 13 have 1 stocks : ['AOT']
# custer 14 have 3 stocks : ['CENTEL', 'CHG', 'THANI']
# custer 15 have 7 stocks : ['BCH', 'CK', 'PTG', 'PTT', 'SCC', 'TRUE', 'VGI']
# custer 16 have 1 stocks : ['BEM']
# custer 17 have 15 stocks : ['BANPU', 'BH', 'CPALL', 'ESSO', 'HMPRO', 'JMT', 'KCE', 'KTC', 'MBK', 'MEGA', 'PSL', 'PTTGC', 'RS', 'STA', 'TASCO']
# custer 18 have 1 stocks : ['BDMS']
# score of window: 1.815020570295294.
# --------------------------------------------------
# window 11:
# custer 1 have 5 stocks : ['ADVANC', 'BEM', 'HMPRO', 'JMT', 'QH']
# custer 2 have 13 stocks : ['AOT', 'BANPU', 'BCP', 'CK', 'DTAC', 'KBANK', 'PTTEP', 'RATCH', 'SCC', 'TCAP', 'TRUE', 'TU', 'VGI']
# custer 3 have 5 stocks : ['KKP', 'ORI', 'PTTGC', 'STPI', 'THAI']
# custer 4 have 6 stocks : ['BEC', 'CHG', 'IRPC', 'PTG', 'SGP', 'TMB']
# custer 5 have 21 stocks : ['BBL', 'BCH', 'CBG', 'CKP', 'ERW', 'ESSO', 'GLOBAL', 'HANA', 'JAS', 'KCE', 'MBK', 'MTC', 'PSL', 'PTT', 'RS', 'SAWAD', 'SCB', 'SPRC', 'TASCO', 'TKN', 'TOP']
# custer 6 have 1 stocks : ['LH']
# custer 7 have 13 stocks : ['BH', 'BJC', 'CPALL', 'DELTA', 'EGCO', 'EPG', 'GFPT', 'INTUCH', 'MEGA', 'PLANB', 'STA', 'STEC', 'TISCO']
# custer 8 have 4 stocks : ['AEONTS', 'CENTEL', 'CPN', 'MINT']
# custer 9 have 1 stocks : ['KTC']
# custer 10 have 1 stocks : ['SUPER']
# custer 11 have 2 stocks : ['SPALI', 'THANI']
# custer 12 have 1 stocks : ['CPF']
# custer 13 have 4 stocks : ['AP', 'COM7', 'MAJOR', 'WHA']
# custer 14 have 1 stocks : ['TTW']
# custer 15 have 2 stocks : ['BDMS', 'KTB']
# custer 16 have 2 stocks : ['EA', 'IVL']
# custer 17 have 1 stocks : ['BTS']
# custer 18 have 1 stocks : ['GUNKUL']
# custer 19 have 2 stocks : ['AMATA', 'GPSC']
# score of window: 1.8411931982364482.
#
#
#
#
# ==================================================
# wavelet: sym2       davies_bouldin_score: 2.000412780298456
# --------------------------------------------------
# window 1:
# custer 1 have 1 stocks : ['JAS']
# custer 2 have 4 stocks : ['BH', 'IVL', 'JMT', 'QH']
# custer 3 have 5 stocks : ['CBG', 'CPALL', 'LH', 'MTC', 'PLANB']
# custer 4 have 1 stocks : ['SAWAD']
# custer 5 have 3 stocks : ['BCP', 'RS', 'STPI']
# custer 6 have 3 stocks : ['AMATA', 'BEC', 'EA']
# custer 7 have 1 stocks : ['TASCO']
# custer 8 have 1 stocks : ['TRUE']
# custer 9 have 1 stocks : ['MBK']
# custer 10 have 2 stocks : ['KTB', 'SCC']
# custer 11 have 1 stocks : ['RATCH']
# custer 12 have 1 stocks : ['TTW']
# custer 13 have 9 stocks : ['AOT', 'BEM', 'GLOBAL', 'HANA', 'PSL', 'PTTGC', 'SCB', 'TOP', 'VGI']
# custer 14 have 2 stocks : ['GPSC', 'TISCO']
# custer 15 have 32 stocks : ['AEONTS', 'AP', 'BANPU', 'BBL', 'BCH', 'CHG', 'CK', 'CKP', 'COM7', 'CPF', 'DTAC', 'EPG', 'ERW', 'GFPT', 'HMPRO', 'IRPC', 'KKP', 'KTC', 'MAJOR', 'MINT', 'ORI', 'PTG', 'PTTEP', 'SGP', 'SPALI', 'STA', 'STEC', 'SUPER', 'TCAP', 'TKN', 'TU', 'WHA']
# custer 16 have 1 stocks : ['GUNKUL']
# custer 17 have 2 stocks : ['ESSO', 'MEGA']
# custer 18 have 16 stocks : ['ADVANC', 'BDMS', 'BJC', 'BTS', 'CENTEL', 'CPN', 'DELTA', 'EGCO', 'INTUCH', 'KBANK', 'KCE', 'PTT', 'SPRC', 'THAI', 'THANI', 'TMB']
# score of window: 1.7534634830057212.
# --------------------------------------------------
# window 2:
# custer 1 have 3 stocks : ['AP', 'BTS', 'MAJOR']
# custer 2 have 26 stocks : ['AEONTS', 'AOT', 'BANPU', 'BEC', 'BEM', 'BH', 'CBG', 'CK', 'COM7', 'CPN', 'DELTA', 'GFPT', 'IVL', 'JMT', 'KBANK', 'KTB', 'KTC', 'MEGA', 'SPALI', 'SPRC', 'STPI', 'TASCO', 'THAI', 'TOP', 'TU', 'VGI']
# custer 3 have 4 stocks : ['EA', 'GLOBAL', 'GPSC', 'PTG']
# custer 4 have 16 stocks : ['AMATA', 'BBL', 'BCP', 'BJC', 'CKP', 'CPF', 'GUNKUL', 'HANA', 'KCE', 'KKP', 'LH', 'PTT', 'SAWAD', 'TCAP', 'TKN', 'TRUE']
# custer 5 have 3 stocks : ['ESSO', 'RATCH', 'THANI']
# custer 6 have 3 stocks : ['INTUCH', 'MBK', 'TISCO']
# custer 7 have 2 stocks : ['DTAC', 'ERW']
# custer 8 have 3 stocks : ['MTC', 'QH', 'SCC']
# custer 9 have 2 stocks : ['TMB', 'TTW']
# custer 10 have 1 stocks : ['PLANB']
# custer 11 have 1 stocks : ['BDMS']
# custer 12 have 1 stocks : ['MINT']
# custer 13 have 1 stocks : ['JAS']
# custer 14 have 20 stocks : ['ADVANC', 'BCH', 'CENTEL', 'CHG', 'CPALL', 'EGCO', 'EPG', 'HMPRO', 'IRPC', 'ORI', 'PSL', 'PTTEP', 'PTTGC', 'RS', 'SCB', 'SGP', 'STA', 'STEC', 'SUPER', 'WHA']
# score of window: 2.1214288524794127.
# --------------------------------------------------
# window 3:
# custer 1 have 16 stocks : ['AMATA', 'AOT', 'BBL', 'BDMS', 'CKP', 'COM7', 'CPN', 'DELTA', 'KCE', 'KTC', 'PTTEP', 'RS', 'SPRC', 'THAI', 'TRUE', 'TTW']
# custer 2 have 13 stocks : ['BCH', 'CPALL', 'DTAC', 'ESSO', 'GFPT', 'JAS', 'MAJOR', 'MTC', 'PTT', 'SAWAD', 'TASCO', 'TISCO', 'TU']
# custer 3 have 3 stocks : ['BCP', 'BTS', 'WHA']
# custer 4 have 3 stocks : ['ERW', 'MEGA', 'RATCH']
# custer 5 have 8 stocks : ['ADVANC', 'CHG', 'EA', 'GPSC', 'IVL', 'KTB', 'LH', 'PTTGC']
# custer 6 have 1 stocks : ['MBK']
# custer 7 have 3 stocks : ['AEONTS', 'IRPC', 'MINT']
# custer 8 have 1 stocks : ['QH']
# custer 9 have 24 stocks : ['AP', 'BANPU', 'BEC', 'BH', 'BJC', 'CENTEL', 'CPF', 'EPG', 'GLOBAL', 'HMPRO', 'INTUCH', 'JMT', 'KBANK', 'PLANB', 'PSL', 'SCB', 'SCC', 'SPALI', 'STA', 'STEC', 'STPI', 'TCAP', 'TKN', 'TOP']
# custer 10 have 14 stocks : ['BEM', 'CBG', 'CK', 'EGCO', 'GUNKUL', 'HANA', 'KKP', 'ORI', 'PTG', 'SGP', 'SUPER', 'THANI', 'TMB', 'VGI']
# score of window: 2.842576340579046.
# --------------------------------------------------
# window 4:
# custer 1 have 1 stocks : ['LH']
# custer 2 have 15 stocks : ['AMATA', 'BBL', 'BEM', 'BJC', 'CENTEL', 'GUNKUL', 'HANA', 'JMT', 'MINT', 'PLANB', 'PTTEP', 'SCB', 'SPRC', 'STA', 'TKN']
# custer 3 have 6 stocks : ['ADVANC', 'BH', 'EGCO', 'ERW', 'TCAP', 'TOP']
# custer 4 have 5 stocks : ['CPF', 'EPG', 'KTB', 'SUPER', 'TRUE']
# custer 5 have 3 stocks : ['BDMS', 'JAS', 'MTC']
# custer 6 have 20 stocks : ['BCP', 'BEC', 'CBG', 'DELTA', 'DTAC', 'ESSO', 'GFPT', 'IRPC', 'KCE', 'KTC', 'ORI', 'PTG', 'PTT', 'RS', 'SAWAD', 'SCC', 'SGP', 'SPALI', 'TASCO', 'THAI']
# custer 7 have 1 stocks : ['MBK']
# custer 8 have 11 stocks : ['CHG', 'CKP', 'COM7', 'EA', 'IVL', 'KBANK', 'MAJOR', 'MEGA', 'QH', 'THANI', 'TISCO']
# custer 9 have 11 stocks : ['AEONTS', 'AOT', 'AP', 'CK', 'CPN', 'HMPRO', 'KKP', 'PSL', 'PTTGC', 'STEC', 'STPI']
# custer 10 have 1 stocks : ['TMB']
# custer 11 have 1 stocks : ['WHA']
# custer 12 have 1 stocks : ['RATCH']
# custer 13 have 2 stocks : ['BTS', 'TTW']
# custer 14 have 1 stocks : ['BCH']
# custer 15 have 2 stocks : ['BANPU', 'VGI']
# custer 16 have 5 stocks : ['CPALL', 'GLOBAL', 'GPSC', 'INTUCH', 'TU']
# score of window: 2.0207783489004276.
# --------------------------------------------------
# window 5:
# custer 1 have 1 stocks : ['AEONTS']
# custer 2 have 8 stocks : ['BJC', 'CHG', 'CPALL', 'MEGA', 'PLANB', 'RATCH', 'RS', 'SPALI']
# custer 3 have 2 stocks : ['KKP', 'KTB']
# custer 4 have 10 stocks : ['BBL', 'BCH', 'BH', 'CENTEL', 'COM7', 'EA', 'GUNKUL', 'IRPC', 'KCE', 'PTT']
# custer 5 have 26 stocks : ['AMATA', 'AOT', 'AP', 'BDMS', 'CBG', 'CKP', 'CPN', 'DELTA', 'GFPT', 'GPSC', 'HANA', 'MBK', 'MINT', 'PSL', 'PTTGC', 'SCB', 'SCC', 'SGP', 'STA', 'STPI', 'TASCO', 'THANI', 'TISCO', 'TMB', 'TOP', 'WHA']
# custer 6 have 1 stocks : ['STEC']
# custer 7 have 8 stocks : ['INTUCH', 'IVL', 'KBANK', 'KTC', 'LH', 'ORI', 'PTG', 'SUPER']
# custer 8 have 1 stocks : ['SPRC']
# custer 9 have 5 stocks : ['DTAC', 'MTC', 'QH', 'SAWAD', 'TU']
# custer 10 have 1 stocks : ['BEM']
# custer 11 have 2 stocks : ['BCP', 'EPG']
# custer 12 have 2 stocks : ['JAS', 'TCAP']
# custer 13 have 10 stocks : ['ADVANC', 'BEC', 'CPF', 'ERW', 'ESSO', 'JMT', 'MAJOR', 'PTTEP', 'THAI', 'TKN']
# custer 14 have 1 stocks : ['TRUE']
# custer 15 have 3 stocks : ['BANPU', 'EGCO', 'VGI']
# custer 16 have 1 stocks : ['CK']
# custer 17 have 1 stocks : ['TTW']
# custer 18 have 2 stocks : ['BTS', 'HMPRO']
# custer 19 have 1 stocks : ['GLOBAL']
# score of window: 1.8442568845235332.
# --------------------------------------------------
# window 6:
# custer 1 have 6 stocks : ['BANPU', 'GLOBAL', 'HMPRO', 'KBANK', 'MEGA', 'MTC']
# custer 2 have 3 stocks : ['BEM', 'CPF', 'TTW']
# custer 3 have 5 stocks : ['AP', 'BCH', 'CBG', 'CHG', 'TMB']
# custer 4 have 1 stocks : ['SUPER']
# custer 5 have 4 stocks : ['KTB', 'TASCO', 'TCAP', 'TU']
# custer 6 have 12 stocks : ['ADVANC', 'BBL', 'BTS', 'CKP', 'DTAC', 'GUNKUL', 'JAS', 'PLANB', 'SCC', 'THAI', 'THANI', 'TISCO']
# custer 7 have 1 stocks : ['STA']
# custer 8 have 46 stocks : ['AEONTS', 'AMATA', 'AOT', 'BCP', 'BDMS', 'BEC', 'BH', 'BJC', 'CENTEL', 'COM7', 'CPALL', 'CPN', 'DELTA', 'EA', 'EGCO', 'ERW', 'ESSO', 'GPSC', 'HANA', 'IRPC', 'IVL', 'JMT', 'KCE', 'KKP', 'KTC', 'MBK', 'MINT', 'ORI', 'PSL', 'PTG', 'PTT', 'PTTEP', 'PTTGC', 'QH', 'RS', 'SAWAD', 'SCB', 'SGP', 'SPALI', 'STEC', 'STPI', 'TKN', 'TOP', 'TRUE', 'VGI', 'WHA']
# custer 9 have 1 stocks : ['GFPT']
# custer 10 have 1 stocks : ['SPRC']
# custer 11 have 2 stocks : ['CK', 'EPG']
# custer 12 have 1 stocks : ['RATCH']
# custer 13 have 1 stocks : ['INTUCH']
# custer 14 have 1 stocks : ['LH']
# custer 15 have 1 stocks : ['MAJOR']
# score of window: 1.6836491364752206.
# --------------------------------------------------
# window 7:
# custer 1 have 1 stocks : ['STEC']
# custer 2 have 3 stocks : ['BEM', 'ORI', 'SPRC']
# custer 3 have 4 stocks : ['CENTEL', 'GPSC', 'IRPC', 'TRUE']
# custer 4 have 7 stocks : ['AOT', 'BTS', 'CK', 'HANA', 'JMT', 'SPALI', 'THAI']
# custer 5 have 9 stocks : ['CHG', 'COM7', 'CPALL', 'DELTA', 'EPG', 'RS', 'TCAP', 'TMB', 'TU']
# custer 6 have 22 stocks : ['AP', 'BDMS', 'BEC', 'CBG', 'CPF', 'CPN', 'ESSO', 'GFPT', 'KBANK', 'KKP', 'MAJOR', 'MBK', 'MTC', 'PTT', 'PTTGC', 'QH', 'SAWAD', 'SCC', 'STA', 'STPI', 'TOP', 'WHA']
# custer 7 have 2 stocks : ['HMPRO', 'THANI']
# custer 8 have 4 stocks : ['ADVANC', 'CKP', 'GLOBAL', 'TASCO']
# custer 9 have 1 stocks : ['RATCH']
# custer 10 have 9 stocks : ['AEONTS', 'BANPU', 'BCH', 'BH', 'DTAC', 'IVL', 'MEGA', 'PTTEP', 'TISCO']
# custer 11 have 1 stocks : ['ERW']
# custer 12 have 12 stocks : ['AMATA', 'BBL', 'BJC', 'EA', 'KCE', 'KTB', 'KTC', 'PLANB', 'PSL', 'PTG', 'SCB', 'SGP']
# custer 13 have 1 stocks : ['VGI']
# custer 14 have 4 stocks : ['EGCO', 'GUNKUL', 'JAS', 'TKN']
# custer 15 have 1 stocks : ['LH']
# custer 16 have 1 stocks : ['TTW']
# custer 17 have 1 stocks : ['INTUCH']
# custer 18 have 1 stocks : ['SUPER']
# custer 19 have 2 stocks : ['BCP', 'MINT']
# score of window: 1.8859910292940392.
# --------------------------------------------------
# window 8:
# custer 1 have 4 stocks : ['EGCO', 'ESSO', 'GUNKUL', 'RATCH']
# custer 2 have 3 stocks : ['CPF', 'PTT', 'QH']
# custer 3 have 17 stocks : ['ADVANC', 'AMATA', 'BEC', 'CBG', 'CENTEL', 'CKP', 'DTAC', 'ERW', 'GFPT', 'GPSC', 'HANA', 'MBK', 'RS', 'SAWAD', 'STEC', 'TCAP', 'TRUE']
# custer 4 have 1 stocks : ['DELTA']
# custer 5 have 1 stocks : ['SPRC']
# custer 6 have 16 stocks : ['AEONTS', 'BEM', 'BH', 'BJC', 'COM7', 'CPALL', 'CPN', 'EA', 'MEGA', 'PSL', 'PTTGC', 'SGP', 'SPALI', 'STPI', 'TOP', 'TU']
# custer 7 have 1 stocks : ['MAJOR']
# custer 8 have 19 stocks : ['AP', 'CHG', 'EPG', 'IVL', 'KBANK', 'KCE', 'ORI', 'PLANB', 'PTG', 'PTTEP', 'SCB', 'SCC', 'TASCO', 'THAI', 'THANI', 'TISCO', 'TKN', 'TMB', 'WHA']
# custer 9 have 2 stocks : ['CK', 'TTW']
# custer 10 have 9 stocks : ['AOT', 'BANPU', 'BCH', 'INTUCH', 'IRPC', 'LH', 'MTC', 'STA', 'SUPER']
# custer 11 have 1 stocks : ['BDMS']
# custer 12 have 1 stocks : ['BTS']
# custer 13 have 3 stocks : ['JMT', 'KTC', 'VGI']
# custer 14 have 2 stocks : ['GLOBAL', 'MINT']
# custer 15 have 1 stocks : ['JAS']
# custer 16 have 3 stocks : ['BBL', 'HMPRO', 'KKP']
# custer 17 have 2 stocks : ['BCP', 'KTB']
# score of window: 1.9808419882374997.
# --------------------------------------------------
# window 9:
# custer 1 have 14 stocks : ['AMATA', 'AOT', 'BCH', 'BDMS', 'KBANK', 'MEGA', 'QH', 'RATCH', 'SCC', 'SPRC', 'STEC', 'THAI', 'TKN', 'VGI']
# custer 2 have 1 stocks : ['ERW']
# custer 3 have 3 stocks : ['HMPRO', 'IRPC', 'IVL']
# custer 4 have 1 stocks : ['MAJOR']
# custer 5 have 6 stocks : ['ADVANC', 'BANPU', 'BH', 'EA', 'GFPT', 'TU']
# custer 6 have 1 stocks : ['SUPER']
# custer 7 have 3 stocks : ['BTS', 'CKP', 'SPALI']
# custer 8 have 1 stocks : ['JAS']
# custer 9 have 6 stocks : ['BEC', 'GLOBAL', 'GUNKUL', 'ORI', 'SGP', 'STA']
# custer 10 have 9 stocks : ['BEM', 'CK', 'EGCO', 'ESSO', 'JMT', 'KKP', 'PTT', 'STPI', 'TISCO']
# custer 11 have 1 stocks : ['BCP']
# custer 12 have 1 stocks : ['LH']
# custer 13 have 11 stocks : ['AEONTS', 'AP', 'BBL', 'BJC', 'CPF', 'CPN', 'MBK', 'MTC', 'PLANB', 'TRUE', 'TTW']
# custer 14 have 1 stocks : ['KTB']
# custer 15 have 24 stocks : ['CBG', 'CENTEL', 'COM7', 'CPALL', 'DTAC', 'EPG', 'GPSC', 'HANA', 'INTUCH', 'KCE', 'KTC', 'MINT', 'PSL', 'PTG', 'PTTEP', 'PTTGC', 'RS', 'SAWAD', 'SCB', 'TASCO', 'TCAP', 'THANI', 'TOP', 'WHA']
# custer 16 have 1 stocks : ['TMB']
# custer 17 have 2 stocks : ['CHG', 'DELTA']
# score of window: 1.8972115254628927.
# --------------------------------------------------
# window 10:
# custer 1 have 2 stocks : ['PLANB', 'TU']
# custer 2 have 6 stocks : ['AP', 'BCP', 'KBANK', 'KTB', 'PTG', 'SCC']
# custer 3 have 12 stocks : ['CBG', 'CK', 'CKP', 'EA', 'HMPRO', 'KTC', 'PTTEP', 'STPI', 'TASCO', 'THANI', 'TRUE', 'VGI']
# custer 4 have 3 stocks : ['BJC', 'THAI', 'TOP']
# custer 5 have 2 stocks : ['QH', 'SUPER']
# custer 6 have 7 stocks : ['COM7', 'GFPT', 'LH', 'MAJOR', 'MINT', 'SGP', 'SPALI']
# custer 7 have 6 stocks : ['AOT', 'GLOBAL', 'GPSC', 'HANA', 'SCB', 'TMB']
# custer 8 have 17 stocks : ['AEONTS', 'AMATA', 'BEC', 'BEM', 'CPALL', 'DTAC', 'ESSO', 'GUNKUL', 'IVL', 'MTC', 'ORI', 'PSL', 'RATCH', 'SAWAD', 'STEC', 'TCAP', 'TKN']
# custer 9 have 4 stocks : ['BBL', 'DELTA', 'JAS', 'JMT']
# custer 10 have 1 stocks : ['IRPC']
# custer 11 have 8 stocks : ['BANPU', 'BH', 'CHG', 'EGCO', 'INTUCH', 'PTT', 'STA', 'TISCO']
# custer 12 have 1 stocks : ['BTS']
# custer 13 have 1 stocks : ['CPF']
# custer 14 have 2 stocks : ['BCH', 'CENTEL']
# custer 15 have 1 stocks : ['ERW']
# custer 16 have 7 stocks : ['EPG', 'KCE', 'KKP', 'MBK', 'MEGA', 'PTTGC', 'RS']
# custer 17 have 3 stocks : ['ADVANC', 'CPN', 'WHA']
# custer 18 have 1 stocks : ['BDMS']
# custer 19 have 2 stocks : ['SPRC', 'TTW']
# score of window: 2.0279203766989324.
# --------------------------------------------------
# window 11:
# custer 1 have 1 stocks : ['VGI']
# custer 2 have 6 stocks : ['CK', 'EGCO', 'KBANK', 'MINT', 'SCB', 'TCAP']
# custer 3 have 8 stocks : ['BDMS', 'CHG', 'CKP', 'CPN', 'GUNKUL', 'KTB', 'TMB', 'TOP']
# custer 4 have 3 stocks : ['CENTEL', 'SPALI', 'THANI']
# custer 5 have 5 stocks : ['KKP', 'ORI', 'PTTGC', 'SGP', 'THAI']
# custer 6 have 11 stocks : ['AP', 'BH', 'CPALL', 'DELTA', 'GFPT', 'JAS', 'MEGA', 'PLANB', 'PTG', 'STEC', 'TISCO']
# custer 7 have 1 stocks : ['BEM']
# custer 8 have 13 stocks : ['BCP', 'BEC', 'DTAC', 'HMPRO', 'INTUCH', 'PSL', 'PTTEP', 'RATCH', 'SCC', 'STPI', 'TASCO', 'TRUE', 'WHA']
# custer 9 have 1 stocks : ['SUPER']
# custer 10 have 2 stocks : ['LH', 'QH']
# custer 11 have 23 stocks : ['ADVANC', 'AEONTS', 'BBL', 'BCH', 'BJC', 'CBG', 'COM7', 'EPG', 'ERW', 'ESSO', 'GLOBAL', 'HANA', 'IVL', 'JMT', 'KCE', 'MBK', 'MTC', 'PTT', 'RS', 'SAWAD', 'SPRC', 'STA', 'TKN']
# custer 12 have 1 stocks : ['TTW']
# custer 13 have 2 stocks : ['AOT', 'MAJOR']
# custer 14 have 1 stocks : ['EA']
# custer 15 have 2 stocks : ['CPF', 'KTC']
# custer 16 have 1 stocks : ['BTS']
# custer 17 have 2 stocks : ['BANPU', 'TU']
# custer 18 have 3 stocks : ['AMATA', 'GPSC', 'IRPC']
# score of window: 1.9464226176262862.
#
#
#
#
# ==================================================
# wavelet: sym3       davies_bouldin_score: 2.050527170466653
# --------------------------------------------------
# window 1:
# custer 1 have 6 stocks : ['EPG', 'ERW', 'INTUCH', 'JAS', 'SAWAD', 'TKN']
# custer 2 have 6 stocks : ['AMATA', 'BEC', 'CENTEL', 'EA', 'SUPER', 'TASCO']
# custer 3 have 4 stocks : ['BCH', 'BDMS', 'HMPRO', 'SGP']
# custer 4 have 8 stocks : ['AOT', 'BEM', 'BJC', 'CBG', 'CPALL', 'KBANK', 'LH', 'MEGA']
# custer 5 have 6 stocks : ['GLOBAL', 'KTB', 'MAJOR', 'QH', 'VGI', 'WHA']
# custer 6 have 12 stocks : ['BANPU', 'BBL', 'CKP', 'ESSO', 'HANA', 'KCE', 'PSL', 'PTTGC', 'SCB', 'STEC', 'THAI', 'TOP']
# custer 7 have 1 stocks : ['TTW']
# custer 8 have 4 stocks : ['BTS', 'COM7', 'JMT', 'ORI']
# custer 9 have 2 stocks : ['GPSC', 'TISCO']
# custer 10 have 1 stocks : ['GUNKUL']
# custer 11 have 17 stocks : ['ADVANC', 'AP', 'BH', 'CHG', 'CPN', 'DELTA', 'DTAC', 'EGCO', 'MTC', 'PLANB', 'PTT', 'PTTEP', 'SCC', 'SPALI', 'STPI', 'THANI', 'TMB']
# custer 12 have 5 stocks : ['AEONTS', 'IRPC', 'PTG', 'RS', 'TCAP']
# custer 13 have 1 stocks : ['RATCH']
# custer 14 have 8 stocks : ['BCP', 'CK', 'GFPT', 'IVL', 'KKP', 'SPRC', 'TRUE', 'TU']
# custer 15 have 1 stocks : ['MBK']
# custer 16 have 4 stocks : ['CPF', 'KTC', 'MINT', 'STA']
# score of window: 2.3125258552598567.
# --------------------------------------------------
# window 2:
# custer 1 have 1 stocks : ['TISCO']
# custer 2 have 30 stocks : ['ADVANC', 'BBL', 'BCH', 'BCP', 'BEC', 'BJC', 'CENTEL', 'CHG', 'CKP', 'CPF', 'CPN', 'EPG', 'IVL', 'KBANK', 'KCE', 'KTB', 'KTC', 'MAJOR', 'PTT', 'PTTEP', 'PTTGC', 'SAWAD', 'SCB', 'SPALI', 'SPRC', 'SUPER', 'TASCO', 'TCAP', 'THAI', 'TRUE']
# custer 3 have 5 stocks : ['AEONTS', 'GPSC', 'HMPRO', 'LH', 'SGP']
# custer 4 have 1 stocks : ['MBK']
# custer 5 have 4 stocks : ['BANPU', 'ERW', 'GFPT', 'JMT']
# custer 6 have 14 stocks : ['AOT', 'BDMS', 'CPALL', 'DELTA', 'EGCO', 'ESSO', 'GUNKUL', 'PLANB', 'PSL', 'RS', 'STEC', 'THANI', 'TOP', 'WHA']
# custer 7 have 2 stocks : ['DTAC', 'MINT']
# custer 8 have 12 stocks : ['BEM', 'COM7', 'EA', 'IRPC', 'MTC', 'ORI', 'SCC', 'STA', 'STPI', 'TTW', 'TU', 'VGI']
# custer 9 have 1 stocks : ['TKN']
# custer 10 have 1 stocks : ['HANA']
# custer 11 have 2 stocks : ['RATCH', 'TMB']
# custer 12 have 6 stocks : ['BH', 'CBG', 'CK', 'INTUCH', 'KKP', 'MEGA']
# custer 13 have 1 stocks : ['QH']
# custer 14 have 2 stocks : ['GLOBAL', 'PTG']
# custer 15 have 1 stocks : ['AMATA']
# custer 16 have 2 stocks : ['AP', 'BTS']
# custer 17 have 1 stocks : ['JAS']
# score of window: 1.7866739481265475.
# --------------------------------------------------
# window 3:
# custer 1 have 2 stocks : ['CK', 'CKP']
# custer 2 have 8 stocks : ['BCH', 'CPF', 'EA', 'IVL', 'PLANB', 'STEC', 'THANI', 'VGI']
# custer 3 have 16 stocks : ['AEONTS', 'AMATA', 'BDMS', 'BEM', 'CBG', 'CENTEL', 'CPN', 'DTAC', 'GFPT', 'HMPRO', 'JMT', 'KTC', 'RS', 'TASCO', 'TTW', 'TU']
# custer 4 have 2 stocks : ['EPG', 'INTUCH']
# custer 5 have 3 stocks : ['CHG', 'CPALL', 'GLOBAL']
# custer 6 have 2 stocks : ['SGP', 'SUPER']
# custer 7 have 12 stocks : ['ADVANC', 'BH', 'BJC', 'EGCO', 'GUNKUL', 'KBANK', 'PTG', 'SCC', 'SPALI', 'STA', 'TCAP', 'TKN']
# custer 8 have 1 stocks : ['QH']
# custer 9 have 2 stocks : ['KTB', 'SCB']
# custer 10 have 1 stocks : ['BTS']
# custer 11 have 1 stocks : ['MINT']
# custer 12 have 1 stocks : ['MBK']
# custer 13 have 11 stocks : ['AP', 'BBL', 'BEC', 'ESSO', 'JAS', 'KKP', 'MAJOR', 'MTC', 'PTT', 'THAI', 'TISCO']
# custer 14 have 4 stocks : ['ERW', 'MEGA', 'ORI', 'RATCH']
# custer 15 have 1 stocks : ['GPSC']
# custer 16 have 2 stocks : ['BCP', 'WHA']
# custer 17 have 16 stocks : ['AOT', 'BANPU', 'COM7', 'DELTA', 'HANA', 'KCE', 'LH', 'PSL', 'PTTEP', 'PTTGC', 'SAWAD', 'SPRC', 'STPI', 'TMB', 'TOP', 'TRUE']
# custer 18 have 1 stocks : ['IRPC']
# score of window: 2.023610987264962.
# --------------------------------------------------
# window 4:
# custer 1 have 9 stocks : ['BCH', 'BEC', 'CKP', 'DTAC', 'HANA', 'KCE', 'MAJOR', 'SPRC', 'THANI']
# custer 2 have 9 stocks : ['ADVANC', 'AP', 'BH', 'CHG', 'JMT', 'KBANK', 'KTC', 'TCAP', 'TOP']
# custer 3 have 4 stocks : ['LH', 'MEGA', 'RATCH', 'STA']
# custer 4 have 5 stocks : ['BEM', 'ERW', 'JAS', 'PTTGC', 'TU']
# custer 5 have 4 stocks : ['GFPT', 'SGP', 'SPALI', 'THAI']
# custer 6 have 4 stocks : ['KTB', 'SUPER', 'TMB', 'TRUE']
# custer 7 have 1 stocks : ['TTW']
# custer 8 have 3 stocks : ['CK', 'MINT', 'SCB']
# custer 9 have 5 stocks : ['AMATA', 'EGCO', 'PLANB', 'PTTEP', 'TKN']
# custer 10 have 2 stocks : ['CPALL', 'GLOBAL']
# custer 11 have 3 stocks : ['GPSC', 'INTUCH', 'MBK']
# custer 12 have 2 stocks : ['QH', 'WHA']
# custer 13 have 16 stocks : ['AEONTS', 'BBL', 'BDMS', 'CBG', 'COM7', 'DELTA', 'EPG', 'ESSO', 'GUNKUL', 'KKP', 'MTC', 'PTG', 'RS', 'SAWAD', 'SCC', 'TISCO']
# custer 14 have 1 stocks : ['BCP']
# custer 15 have 3 stocks : ['BJC', 'EA', 'IVL']
# custer 16 have 4 stocks : ['BANPU', 'CPF', 'PTT', 'TASCO']
# custer 17 have 1 stocks : ['VGI']
# custer 18 have 1 stocks : ['BTS']
# custer 19 have 9 stocks : ['AOT', 'CENTEL', 'CPN', 'HMPRO', 'IRPC', 'ORI', 'PSL', 'STEC', 'STPI']
# score of window: 2.2226163854117647.
# --------------------------------------------------
# window 5:
# custer 1 have 5 stocks : ['BDMS', 'CK', 'HMPRO', 'JMT', 'WHA']
# custer 2 have 6 stocks : ['AEONTS', 'AP', 'BBL', 'BCP', 'GPSC', 'SPALI']
# custer 3 have 2 stocks : ['GLOBAL', 'QH']
# custer 4 have 7 stocks : ['ADVANC', 'CPN', 'ESSO', 'MBK', 'MTC', 'TASCO', 'TISCO']
# custer 5 have 2 stocks : ['IRPC', 'SPRC']
# custer 6 have 9 stocks : ['EPG', 'KKP', 'KTB', 'LH', 'RS', 'SCB', 'STA', 'STEC', 'VGI']
# custer 7 have 1 stocks : ['TTW']
# custer 8 have 1 stocks : ['TRUE']
# custer 9 have 27 stocks : ['AMATA', 'AOT', 'BCH', 'BEC', 'BH', 'CBG', 'CENTEL', 'CHG', 'COM7', 'CPF', 'DELTA', 'GUNKUL', 'HANA', 'KCE', 'KTC', 'MEGA', 'ORI', 'PLANB', 'PSL', 'PTG', 'PTT', 'PTTEP', 'PTTGC', 'RATCH', 'SGP', 'THANI', 'TKN']
# custer 10 have 1 stocks : ['BEM']
# custer 11 have 1 stocks : ['CPALL']
# custer 12 have 3 stocks : ['INTUCH', 'JAS', 'TCAP']
# custer 13 have 2 stocks : ['BANPU', 'BTS']
# custer 14 have 19 stocks : ['BJC', 'CKP', 'DTAC', 'EA', 'EGCO', 'ERW', 'GFPT', 'IVL', 'KBANK', 'MAJOR', 'MINT', 'SAWAD', 'SCC', 'STPI', 'SUPER', 'THAI', 'TMB', 'TOP', 'TU']
# score of window: 2.2393804415913325.
# --------------------------------------------------
# window 6:
# custer 1 have 23 stocks : ['AMATA', 'BBL', 'BCP', 'BJC', 'COM7', 'DELTA', 'EA', 'EGCO', 'ERW', 'IVL', 'KBANK', 'KTC', 'MEGA', 'ORI', 'PLANB', 'PSL', 'PTT', 'SAWAD', 'TASCO', 'THAI', 'THANI', 'TOP', 'TU']
# custer 2 have 1 stocks : ['KTB']
# custer 3 have 3 stocks : ['INTUCH', 'KCE', 'LH']
# custer 4 have 3 stocks : ['BDMS', 'EPG', 'RATCH']
# custer 5 have 1 stocks : ['CK']
# custer 6 have 7 stocks : ['AEONTS', 'BANPU', 'CENTEL', 'GPSC', 'MBK', 'SGP', 'STEC']
# custer 7 have 20 stocks : ['AOT', 'BEC', 'CBG', 'CHG', 'CPALL', 'GUNKUL', 'HANA', 'JAS', 'KKP', 'MINT', 'PTG', 'PTTGC', 'QH', 'RS', 'SCB', 'SPALI', 'SPRC', 'STPI', 'TMB', 'WHA']
# custer 8 have 8 stocks : ['BCH', 'BH', 'DTAC', 'GLOBAL', 'PTTEP', 'STA', 'TKN', 'VGI']
# custer 9 have 2 stocks : ['ADVANC', 'CKP']
# custer 10 have 2 stocks : ['MTC', 'SUPER']
# custer 11 have 1 stocks : ['AP']
# custer 12 have 1 stocks : ['GFPT']
# custer 13 have 1 stocks : ['TCAP']
# custer 14 have 8 stocks : ['CPN', 'ESSO', 'HMPRO', 'IRPC', 'JMT', 'SCC', 'TISCO', 'TRUE']
# custer 15 have 3 stocks : ['BEM', 'CPF', 'TTW']
# custer 16 have 1 stocks : ['MAJOR']
# custer 17 have 1 stocks : ['BTS']
# score of window: 1.9477498574515646.
# --------------------------------------------------
# window 7:
# custer 1 have 1 stocks : ['MEGA']
# custer 2 have 22 stocks : ['ADVANC', 'AOT', 'AP', 'CBG', 'COM7', 'CPALL', 'CPN', 'IRPC', 'KBANK', 'KTB', 'MBK', 'MTC', 'PTT', 'PTTGC', 'RS', 'SAWAD', 'SCC', 'SPALI', 'STA', 'STPI', 'TOP', 'WHA']
# custer 3 have 4 stocks : ['BEM', 'KKP', 'ORI', 'SPRC']
# custer 4 have 2 stocks : ['INTUCH', 'JMT']
# custer 5 have 8 stocks : ['BCP', 'BDMS', 'CHG', 'EA', 'GLOBAL', 'GPSC', 'PLANB', 'SUPER']
# custer 6 have 8 stocks : ['AEONTS', 'BANPU', 'BCH', 'BH', 'DTAC', 'IVL', 'PTTEP', 'TISCO']
# custer 7 have 9 stocks : ['CENTEL', 'DELTA', 'EPG', 'MAJOR', 'QH', 'TASCO', 'TCAP', 'TMB', 'TU']
# custer 8 have 1 stocks : ['LH']
# custer 9 have 1 stocks : ['RATCH']
# custer 10 have 1 stocks : ['VGI']
# custer 11 have 1 stocks : ['BTS']
# custer 12 have 1 stocks : ['CK']
# custer 13 have 1 stocks : ['TTW']
# custer 14 have 12 stocks : ['AMATA', 'BBL', 'BJC', 'CKP', 'GUNKUL', 'KCE', 'KTC', 'PSL', 'PTG', 'SCB', 'SGP', 'STEC']
# custer 15 have 2 stocks : ['HMPRO', 'THANI']
# custer 16 have 1 stocks : ['GFPT']
# custer 17 have 2 stocks : ['EGCO', 'JAS']
# custer 18 have 9 stocks : ['BEC', 'CPF', 'ERW', 'ESSO', 'HANA', 'MINT', 'THAI', 'TKN', 'TRUE']
# score of window: 1.8636321777324925.
# --------------------------------------------------
# window 8:
# custer 1 have 5 stocks : ['BTS', 'GFPT', 'JMT', 'KTC', 'STEC']
# custer 2 have 12 stocks : ['AP', 'BEM', 'BH', 'CPN', 'MAJOR', 'MEGA', 'SGP', 'STPI', 'TASCO', 'THANI', 'TOP', 'TU']
# custer 3 have 4 stocks : ['CENTEL', 'ERW', 'SAWAD', 'VGI']
# custer 4 have 9 stocks : ['BANPU', 'KTB', 'MTC', 'PTT', 'PTTGC', 'QH', 'SCC', 'SPALI', 'STA']
# custer 5 have 3 stocks : ['CHG', 'LH', 'SPRC']
# custer 6 have 1 stocks : ['BCP']
# custer 7 have 1 stocks : ['TMB']
# custer 8 have 1 stocks : ['BDMS']
# custer 9 have 1 stocks : ['DELTA']
# custer 10 have 2 stocks : ['CK', 'JAS']
# custer 11 have 3 stocks : ['BCH', 'KCE', 'SUPER']
# custer 12 have 1 stocks : ['TTW']
# custer 13 have 15 stocks : ['AMATA', 'BJC', 'CKP', 'COM7', 'CPALL', 'DTAC', 'EA', 'ESSO', 'GLOBAL', 'HANA', 'MINT', 'PTG', 'TISCO', 'TKN', 'WHA']
# custer 14 have 4 stocks : ['EGCO', 'GUNKUL', 'PSL', 'RATCH']
# custer 15 have 14 stocks : ['ADVANC', 'AEONTS', 'AOT', 'BBL', 'BEC', 'IVL', 'KBANK', 'KKP', 'ORI', 'PLANB', 'PTTEP', 'SCB', 'THAI', 'TRUE']
# custer 16 have 7 stocks : ['CBG', 'CPF', 'EPG', 'GPSC', 'MBK', 'RS', 'TCAP']
# custer 17 have 1 stocks : ['HMPRO']
# custer 18 have 2 stocks : ['INTUCH', 'IRPC']
# score of window: 2.046104704042056.
# --------------------------------------------------
# window 9:
# custer 1 have 2 stocks : ['CHG', 'IRPC']
# custer 2 have 7 stocks : ['AEONTS', 'BEM', 'GPSC', 'MAJOR', 'MTC', 'PSL', 'STPI']
# custer 3 have 1 stocks : ['BCP']
# custer 4 have 33 stocks : ['AOT', 'BDMS', 'BEC', 'BH', 'CBG', 'COM7', 'CPALL', 'CPN', 'DTAC', 'EA', 'GLOBAL', 'HANA', 'HMPRO', 'INTUCH', 'IVL', 'KBANK', 'KCE', 'KTC', 'MINT', 'PLANB', 'PTTEP', 'PTTGC', 'RS', 'SCB', 'SGP', 'SPALI', 'STA', 'STEC', 'TASCO', 'TCAP', 'TKN', 'TOP', 'TRUE']
# custer 5 have 1 stocks : ['ERW']
# custer 6 have 3 stocks : ['BBL', 'JMT', 'SPRC']
# custer 7 have 1 stocks : ['DELTA']
# custer 8 have 5 stocks : ['AP', 'ESSO', 'RATCH', 'SCC', 'TTW']
# custer 9 have 4 stocks : ['ADVANC', 'CKP', 'CPF', 'GFPT']
# custer 10 have 10 stocks : ['AMATA', 'BCH', 'BJC', 'CK', 'KKP', 'PTG', 'PTT', 'QH', 'TISCO', 'VGI']
# custer 11 have 1 stocks : ['SUPER']
# custer 12 have 1 stocks : ['JAS']
# custer 13 have 1 stocks : ['TMB']
# custer 14 have 2 stocks : ['BTS', 'LH']
# custer 15 have 14 stocks : ['BANPU', 'CENTEL', 'EGCO', 'EPG', 'GUNKUL', 'KTB', 'MBK', 'MEGA', 'ORI', 'SAWAD', 'THAI', 'THANI', 'TU', 'WHA']
# score of window: 2.0111567137047843.
# --------------------------------------------------
# window 10:
# custer 1 have 6 stocks : ['HMPRO', 'MINT', 'STPI', 'THAI', 'TRUE', 'VGI']
# custer 2 have 6 stocks : ['BCH', 'EPG', 'KCE', 'MBK', 'PTTGC', 'STEC']
# custer 3 have 1 stocks : ['CPF']
# custer 4 have 5 stocks : ['AOT', 'BEM', 'CPALL', 'PSL', 'SPALI']
# custer 5 have 2 stocks : ['CHG', 'TMB']
# custer 6 have 2 stocks : ['QH', 'SUPER']
# custer 7 have 1 stocks : ['GLOBAL']
# custer 8 have 6 stocks : ['COM7', 'DTAC', 'PLANB', 'TCAP', 'THANI', 'WHA']
# custer 9 have 12 stocks : ['AP', 'BANPU', 'BBL', 'BH', 'INTUCH', 'JMT', 'KBANK', 'KTC', 'MAJOR', 'PTT', 'RS', 'STA']
# custer 10 have 2 stocks : ['IRPC', 'TOP']
# custer 11 have 1 stocks : ['BTS']
# custer 12 have 4 stocks : ['BCP', 'SCC', 'SPRC', 'TTW']
# custer 13 have 12 stocks : ['BJC', 'EGCO', 'HANA', 'KKP', 'KTB', 'MEGA', 'PTG', 'SGP', 'TASCO', 'TISCO', 'TKN', 'TU']
# custer 14 have 1 stocks : ['JAS']
# custer 15 have 4 stocks : ['ADVANC', 'AEONTS', 'CPN', 'GUNKUL']
# custer 16 have 15 stocks : ['BEC', 'CBG', 'CENTEL', 'CK', 'CKP', 'DELTA', 'EA', 'ESSO', 'IVL', 'MTC', 'ORI', 'PTTEP', 'RATCH', 'SAWAD', 'SCB']
# custer 17 have 1 stocks : ['ERW']
# custer 18 have 3 stocks : ['BDMS', 'GFPT', 'LH']
# custer 19 have 2 stocks : ['AMATA', 'GPSC']
# score of window: 2.0878078710949284.
# --------------------------------------------------
# window 11:
# custer 1 have 2 stocks : ['EPG', 'TU']
# custer 2 have 5 stocks : ['KKP', 'ORI', 'PTTGC', 'STPI', 'THAI']
# custer 3 have 7 stocks : ['AP', 'BCH', 'HANA', 'MAJOR', 'MEGA', 'PTG', 'SCC']
# custer 4 have 11 stocks : ['AMATA', 'BH', 'BJC', 'GFPT', 'GPSC', 'JAS', 'PLANB', 'SGP', 'SPALI', 'STEC', 'TASCO']
# custer 5 have 9 stocks : ['AEONTS', 'BTS', 'CPN', 'ERW', 'GLOBAL', 'IVL', 'MINT', 'MTC', 'THANI']
# custer 6 have 1 stocks : ['LH']
# custer 7 have 7 stocks : ['BEC', 'CBG', 'DELTA', 'EA', 'KTC', 'RS', 'TMB']
# custer 8 have 1 stocks : ['CENTEL']
# custer 9 have 2 stocks : ['AOT', 'BDMS']
# custer 10 have 5 stocks : ['CPALL', 'EGCO', 'MBK', 'STA', 'TISCO']
# custer 11 have 13 stocks : ['ADVANC', 'BBL', 'CKP', 'ESSO', 'INTUCH', 'IRPC', 'JMT', 'PSL', 'PTT', 'SAWAD', 'SPRC', 'TKN', 'TOP']
# custer 12 have 2 stocks : ['CHG', 'CPF']
# custer 13 have 1 stocks : ['BEM']
# custer 14 have 1 stocks : ['SUPER']
# custer 15 have 2 stocks : ['BANPU', 'TTW']
# custer 16 have 15 stocks : ['BCP', 'CK', 'COM7', 'DTAC', 'GUNKUL', 'HMPRO', 'KBANK', 'KCE', 'PTTEP', 'RATCH', 'SCB', 'TCAP', 'TRUE', 'VGI', 'WHA']
# custer 17 have 1 stocks : ['KTB']
# custer 18 have 1 stocks : ['QH']
# score of window: 2.0145399334528897.
#
#
#
#
# ==================================================
# wavelet: sym16      davies_bouldin_score: 1.9088259838560513
# --------------------------------------------------
# window 1:
# custer 1 have 4 stocks : ['CPN', 'DELTA', 'GPSC', 'TMB']
# custer 2 have 5 stocks : ['GLOBAL', 'INTUCH', 'KTC', 'MINT', 'STA']
# custer 3 have 9 stocks : ['AOT', 'BEM', 'BJC', 'CBG', 'KBANK', 'KCE', 'PSL', 'PTTGC', 'SCB']
# custer 4 have 2 stocks : ['BDMS', 'MBK']
# custer 5 have 5 stocks : ['CPALL', 'EGCO', 'HANA', 'JMT', 'TOP']
# custer 6 have 7 stocks : ['BTS', 'COM7', 'GFPT', 'KKP', 'SPRC', 'TRUE', 'TU']
# custer 7 have 3 stocks : ['BCP', 'RS', 'STPI']
# custer 8 have 2 stocks : ['SAWAD', 'TKN']
# custer 9 have 3 stocks : ['AP', 'LH', 'THANI']
# custer 10 have 1 stocks : ['TASCO']
# custer 11 have 2 stocks : ['HMPRO', 'SGP']
# custer 12 have 1 stocks : ['GUNKUL']
# custer 13 have 1 stocks : ['RATCH']
# custer 14 have 33 stocks : ['ADVANC', 'AEONTS', 'BANPU', 'BBL', 'BCH', 'BH', 'CENTEL', 'CHG', 'CK', 'CKP', 'CPF', 'DTAC', 'EPG', 'ERW', 'IRPC', 'IVL', 'JAS', 'KTB', 'MAJOR', 'ORI', 'PTG', 'PTT', 'PTTEP', 'QH', 'SCC', 'SPALI', 'STEC', 'SUPER', 'TCAP', 'THAI', 'TISCO', 'VGI', 'WHA']
# custer 15 have 1 stocks : ['PLANB']
# custer 16 have 2 stocks : ['ESSO', 'MEGA']
# custer 17 have 3 stocks : ['AMATA', 'BEC', 'EA']
# custer 18 have 1 stocks : ['MTC']
# custer 19 have 1 stocks : ['TTW']
# score of window: 1.8107462109781238.
# --------------------------------------------------
# window 2:
# custer 1 have 2 stocks : ['TISCO', 'TRUE']
# custer 2 have 12 stocks : ['BBL', 'BEC', 'CPALL', 'CPF', 'GUNKUL', 'HANA', 'KCE', 'PTTGC', 'SPRC', 'TASCO', 'THAI', 'THANI']
# custer 3 have 2 stocks : ['AMATA', 'INTUCH']
# custer 4 have 3 stocks : ['BCP', 'BDMS', 'PSL']
# custer 5 have 16 stocks : ['BH', 'CBG', 'CK', 'COM7', 'EGCO', 'EPG', 'GPSC', 'KTC', 'MEGA', 'PTT', 'PTTEP', 'SCB', 'SGP', 'STA', 'STEC', 'SUPER']
# custer 6 have 4 stocks : ['AOT', 'QH', 'TCAP', 'TTW']
# custer 7 have 5 stocks : ['ADVANC', 'AP', 'CHG', 'KBANK', 'MAJOR']
# custer 8 have 9 stocks : ['AEONTS', 'BCH', 'BJC', 'HMPRO', 'IVL', 'KTB', 'LH', 'MTC', 'SAWAD']
# custer 9 have 1 stocks : ['TMB']
# custer 10 have 12 stocks : ['BANPU', 'CPN', 'DELTA', 'DTAC', 'ERW', 'ESSO', 'GFPT', 'RATCH', 'RS', 'SCC', 'SPALI', 'TOP']
# custer 11 have 1 stocks : ['MINT']
# custer 12 have 4 stocks : ['JMT', 'STPI', 'VGI', 'WHA']
# custer 13 have 2 stocks : ['IRPC', 'ORI']
# custer 14 have 1 stocks : ['PLANB']
# custer 15 have 1 stocks : ['JAS']
# custer 16 have 3 stocks : ['CENTEL', 'GLOBAL', 'PTG']
# custer 17 have 1 stocks : ['MBK']
# custer 18 have 1 stocks : ['BTS']
# custer 19 have 6 stocks : ['BEM', 'CKP', 'EA', 'KKP', 'TKN', 'TU']
# score of window: 1.98068414999491.
# --------------------------------------------------
# window 3:
# custer 1 have 1 stocks : ['QH']
# custer 2 have 10 stocks : ['BCP', 'BDMS', 'GPSC', 'KBANK', 'KCE', 'KTB', 'LH', 'SPALI', 'THAI', 'TRUE']
# custer 3 have 2 stocks : ['EPG', 'PTTGC']
# custer 4 have 9 stocks : ['AP', 'BEC', 'CENTEL', 'GLOBAL', 'INTUCH', 'KKP', 'SCB', 'STPI', 'TCAP']
# custer 5 have 7 stocks : ['AEONTS', 'CPF', 'EA', 'ERW', 'STEC', 'THANI', 'TU']
# custer 6 have 5 stocks : ['CPN', 'HMPRO', 'JMT', 'TASCO', 'VGI']
# custer 7 have 4 stocks : ['CBG', 'CHG', 'CPALL', 'TISCO']
# custer 8 have 21 stocks : ['ADVANC', 'AOT', 'BBL', 'BEM', 'BH', 'BJC', 'COM7', 'DELTA', 'DTAC', 'EGCO', 'GFPT', 'MEGA', 'MTC', 'ORI', 'PSL', 'PTT', 'PTTEP', 'SAWAD', 'STA', 'TOP', 'WHA']
# custer 9 have 1 stocks : ['RATCH']
# custer 10 have 6 stocks : ['BCH', 'IVL', 'JAS', 'PLANB', 'PTG', 'SCC']
# custer 11 have 3 stocks : ['BTS', 'TMB', 'TTW']
# custer 12 have 2 stocks : ['CK', 'CKP']
# custer 13 have 3 stocks : ['AMATA', 'GUNKUL', 'HANA']
# custer 14 have 1 stocks : ['MINT']
# custer 15 have 1 stocks : ['MBK']
# custer 16 have 2 stocks : ['BANPU', 'RS']
# custer 17 have 5 stocks : ['ESSO', 'KTC', 'MAJOR', 'SPRC', 'TKN']
# custer 18 have 1 stocks : ['IRPC']
# custer 19 have 2 stocks : ['SGP', 'SUPER']
# score of window: 1.9957493708285128.
# --------------------------------------------------
# window 4:
# custer 1 have 2 stocks : ['BDMS', 'MTC']
# custer 2 have 4 stocks : ['AP', 'EPG', 'SPALI', 'SUPER']
# custer 3 have 20 stocks : ['AOT', 'BCP', 'BEC', 'BH', 'CBG', 'CENTEL', 'DELTA', 'DTAC', 'GUNKUL', 'KCE', 'KKP', 'KTC', 'MAJOR', 'PTT', 'PTTEP', 'SCC', 'SPRC', 'THAI', 'THANI', 'TOP']
# custer 4 have 6 stocks : ['BCH', 'CK', 'PLANB', 'PTG', 'RS', 'SAWAD']
# custer 5 have 6 stocks : ['BEM', 'BTS', 'ERW', 'JAS', 'PTTGC', 'TU']
# custer 6 have 3 stocks : ['BJC', 'STA', 'STEC']
# custer 7 have 4 stocks : ['BBL', 'COM7', 'ESSO', 'KTB']
# custer 8 have 2 stocks : ['IVL', 'QH']
# custer 9 have 2 stocks : ['CPF', 'WHA']
# custer 10 have 5 stocks : ['EA', 'GFPT', 'SGP', 'TISCO', 'TRUE']
# custer 11 have 3 stocks : ['AMATA', 'MINT', 'TKN']
# custer 12 have 6 stocks : ['AEONTS', 'CKP', 'CPN', 'GLOBAL', 'MEGA', 'SCB']
# custer 13 have 5 stocks : ['ADVANC', 'CHG', 'CPALL', 'KBANK', 'TCAP']
# custer 14 have 1 stocks : ['RATCH']
# custer 15 have 1 stocks : ['TTW']
# custer 16 have 2 stocks : ['BANPU', 'VGI']
# custer 17 have 1 stocks : ['LH']
# custer 18 have 3 stocks : ['GPSC', 'INTUCH', 'MBK']
# custer 19 have 10 stocks : ['EGCO', 'HANA', 'HMPRO', 'IRPC', 'JMT', 'ORI', 'PSL', 'STPI', 'TASCO', 'TMB']
# score of window: 2.0788599432582573.
# --------------------------------------------------
# window 5:
# custer 1 have 9 stocks : ['BJC', 'CHG', 'GUNKUL', 'LH', 'PTTGC', 'SPALI', 'STA', 'THAI', 'WHA']
# custer 2 have 26 stocks : ['AMATA', 'BDMS', 'BEC', 'BH', 'CBG', 'CKP', 'CPF', 'DELTA', 'ERW', 'GFPT', 'GPSC', 'HANA', 'KBANK', 'KKP', 'KTC', 'MEGA', 'ORI', 'PSL', 'PTG', 'PTTEP', 'RS', 'SAWAD', 'SCB', 'THANI', 'TKN', 'TOP']
# custer 3 have 5 stocks : ['BBL', 'BCP', 'COM7', 'HMPRO', 'MINT']
# custer 4 have 11 stocks : ['ADVANC', 'CPALL', 'CPN', 'IVL', 'MBK', 'PLANB', 'PTT', 'RATCH', 'SGP', 'TASCO', 'TMB']
# custer 5 have 3 stocks : ['EPG', 'JAS', 'SCC']
# custer 6 have 1 stocks : ['STEC']
# custer 7 have 1 stocks : ['KTB']
# custer 8 have 1 stocks : ['CK']
# custer 9 have 2 stocks : ['AEONTS', 'BEM']
# custer 10 have 1 stocks : ['BTS']
# custer 11 have 2 stocks : ['GLOBAL', 'QH']
# custer 12 have 1 stocks : ['SPRC']
# custer 13 have 3 stocks : ['BANPU', 'MAJOR', 'TRUE']
# custer 14 have 1 stocks : ['VGI']
# custer 15 have 7 stocks : ['AP', 'DTAC', 'ESSO', 'JMT', 'STPI', 'SUPER', 'TISCO']
# custer 16 have 2 stocks : ['INTUCH', 'TCAP']
# custer 17 have 8 stocks : ['AOT', 'BCH', 'CENTEL', 'EA', 'EGCO', 'IRPC', 'KCE', 'TU']
# custer 18 have 2 stocks : ['MTC', 'TTW']
# score of window: 1.7497609390550388.
# --------------------------------------------------
# window 6:
# custer 1 have 8 stocks : ['ADVANC', 'CPALL', 'GFPT', 'HANA', 'PLANB', 'PSL', 'SPALI', 'WHA']
# custer 2 have 11 stocks : ['AOT', 'BDMS', 'BEC', 'DELTA', 'EGCO', 'KBANK', 'MBK', 'PTT', 'RATCH', 'RS', 'SPRC']
# custer 3 have 18 stocks : ['BBL', 'EA', 'GUNKUL', 'IRPC', 'KKP', 'KTC', 'ORI', 'PTG', 'PTTGC', 'QH', 'SAWAD', 'SCB', 'SCC', 'STPI', 'TASCO', 'THANI', 'TOP', 'TU']
# custer 4 have 3 stocks : ['BCP', 'BEM', 'JAS']
# custer 5 have 1 stocks : ['TTW']
# custer 6 have 12 stocks : ['AEONTS', 'BCH', 'BH', 'CENTEL', 'CKP', 'DTAC', 'GLOBAL', 'IVL', 'MEGA', 'PTTEP', 'TISCO', 'VGI']
# custer 7 have 2 stocks : ['STEC', 'THAI']
# custer 8 have 3 stocks : ['CBG', 'CHG', 'TMB']
# custer 9 have 1 stocks : ['MTC']
# custer 10 have 7 stocks : ['AMATA', 'AP', 'BJC', 'ERW', 'GPSC', 'JMT', 'SGP']
# custer 11 have 1 stocks : ['BTS']
# custer 12 have 7 stocks : ['BANPU', 'COM7', 'CPF', 'CPN', 'EPG', 'ESSO', 'HMPRO']
# custer 13 have 1 stocks : ['MAJOR']
# custer 14 have 1 stocks : ['TCAP']
# custer 15 have 1 stocks : ['STA']
# custer 16 have 1 stocks : ['SUPER']
# custer 17 have 2 stocks : ['KTB', 'TRUE']
# custer 18 have 3 stocks : ['CK', 'MINT', 'TKN']
# custer 19 have 3 stocks : ['INTUCH', 'KCE', 'LH']
# score of window: 1.864385719383141.
# --------------------------------------------------
# window 7:
# custer 1 have 6 stocks : ['COM7', 'CPALL', 'CPF', 'KTB', 'MINT', 'TKN']
# custer 2 have 3 stocks : ['RS', 'SPRC', 'TCAP']
# custer 3 have 29 stocks : ['ADVANC', 'AP', 'BEC', 'CBG', 'CKP', 'CPN', 'EPG', 'ERW', 'ESSO', 'GFPT', 'GLOBAL', 'IRPC', 'JMT', 'KBANK', 'KCE', 'KTC', 'MBK', 'MTC', 'ORI', 'PTG', 'PTT', 'PTTGC', 'SCC', 'SGP', 'SPALI', 'STEC', 'STPI', 'TOP', 'WHA']
# custer 4 have 10 stocks : ['AMATA', 'BBL', 'BDMS', 'BJC', 'EA', 'EGCO', 'INTUCH', 'PLANB', 'PSL', 'SCB']
# custer 5 have 1 stocks : ['VGI']
# custer 6 have 1 stocks : ['RATCH']
# custer 7 have 2 stocks : ['BCH', 'STA']
# custer 8 have 8 stocks : ['AEONTS', 'BANPU', 'BH', 'DTAC', 'GPSC', 'IVL', 'PTTEP', 'TISCO']
# custer 9 have 1 stocks : ['AOT']
# custer 10 have 13 stocks : ['CENTEL', 'CHG', 'DELTA', 'HANA', 'KKP', 'MAJOR', 'MEGA', 'QH', 'SAWAD', 'TASCO', 'TMB', 'TRUE', 'TU']
# custer 11 have 1 stocks : ['BTS']
# custer 12 have 1 stocks : ['LH']
# custer 13 have 2 stocks : ['JAS', 'THANI']
# custer 14 have 1 stocks : ['CK']
# custer 15 have 1 stocks : ['THAI']
# custer 16 have 1 stocks : ['TTW']
# custer 17 have 3 stocks : ['BCP', 'GUNKUL', 'SUPER']
# custer 18 have 2 stocks : ['BEM', 'HMPRO']
# score of window: 1.7947603339825509.
# --------------------------------------------------
# window 8:
# custer 1 have 3 stocks : ['BCP', 'GUNKUL', 'SUPER']
# custer 2 have 11 stocks : ['AP', 'BANPU', 'BEC', 'CHG', 'HANA', 'KBANK', 'MAJOR', 'PLANB', 'PTG', 'TOP', 'WHA']
# custer 3 have 4 stocks : ['CBG', 'GPSC', 'RS', 'STEC']
# custer 4 have 3 stocks : ['CK', 'LH', 'SPRC']
# custer 5 have 13 stocks : ['AEONTS', 'BCH', 'CENTEL', 'COM7', 'ERW', 'GLOBAL', 'JMT', 'KCE', 'MINT', 'ORI', 'SCC', 'SGP', 'TASCO']
# custer 6 have 4 stocks : ['BBL', 'KKP', 'KTC', 'TCAP']
# custer 7 have 3 stocks : ['INTUCH', 'IRPC', 'TMB']
# custer 8 have 11 stocks : ['ADVANC', 'AOT', 'BEM', 'BJC', 'CPN', 'EGCO', 'PSL', 'PTTEP', 'STPI', 'THAI', 'THANI']
# custer 9 have 9 stocks : ['CPF', 'GFPT', 'MBK', 'MTC', 'PTT', 'PTTGC', 'QH', 'SPALI', 'STA']
# custer 10 have 1 stocks : ['BTS']
# custer 11 have 3 stocks : ['EPG', 'HMPRO', 'VGI']
# custer 12 have 1 stocks : ['BDMS']
# custer 13 have 1 stocks : ['TTW']
# custer 14 have 1 stocks : ['RATCH']
# custer 15 have 1 stocks : ['JAS']
# custer 16 have 1 stocks : ['KTB']
# custer 17 have 15 stocks : ['AMATA', 'BH', 'CKP', 'CPALL', 'DTAC', 'EA', 'ESSO', 'IVL', 'MEGA', 'SAWAD', 'SCB', 'TISCO', 'TKN', 'TRUE', 'TU']
# custer 18 have 1 stocks : ['DELTA']
# score of window: 1.938867880825164.
# --------------------------------------------------
# window 9:
# custer 1 have 30 stocks : ['ADVANC', 'AEONTS', 'AMATA', 'BBL', 'BEC', 'CBG', 'CENTEL', 'COM7', 'CPN', 'EGCO', 'ESSO', 'GFPT', 'GPSC', 'HANA', 'IVL', 'KCE', 'KTC', 'MINT', 'ORI', 'PLANB', 'PSL', 'PTTGC', 'RS', 'SAWAD', 'SGP', 'TCAP', 'THANI', 'TKN', 'VGI', 'WHA']
# custer 2 have 2 stocks : ['KTB', 'THAI']
# custer 3 have 1 stocks : ['LH']
# custer 4 have 9 stocks : ['BH', 'CKP', 'CPALL', 'EA', 'HMPRO', 'INTUCH', 'MEGA', 'SPALI', 'TU']
# custer 5 have 14 stocks : ['AOT', 'AP', 'BCH', 'BDMS', 'DTAC', 'ERW', 'GLOBAL', 'KBANK', 'MBK', 'QH', 'RATCH', 'SCC', 'STA', 'STEC']
# custer 6 have 1 stocks : ['CPF']
# custer 7 have 4 stocks : ['CK', 'PTT', 'PTTEP', 'TRUE']
# custer 8 have 2 stocks : ['IRPC', 'TOP']
# custer 9 have 12 stocks : ['BANPU', 'BEM', 'EPG', 'GUNKUL', 'JAS', 'JMT', 'KKP', 'MAJOR', 'MTC', 'SCB', 'STPI', 'TASCO']
# custer 10 have 1 stocks : ['SUPER']
# custer 11 have 1 stocks : ['SPRC']
# custer 12 have 1 stocks : ['TTW']
# custer 13 have 1 stocks : ['TMB']
# custer 14 have 2 stocks : ['CHG', 'DELTA']
# custer 15 have 1 stocks : ['BCP']
# custer 16 have 1 stocks : ['BTS']
# custer 17 have 3 stocks : ['BJC', 'PTG', 'TISCO']
# score of window: 1.7132781649890125.
# --------------------------------------------------
# window 10:
# custer 1 have 2 stocks : ['DELTA', 'TU']
# custer 2 have 3 stocks : ['CHG', 'MINT', 'MTC']
# custer 3 have 19 stocks : ['ADVANC', 'AEONTS', 'AMATA', 'BANPU', 'BEC', 'BEM', 'CPN', 'DTAC', 'EGCO', 'ESSO', 'INTUCH', 'IVL', 'ORI', 'PTTEP', 'PTTGC', 'SAWAD', 'SCB', 'TCAP', 'THANI']
# custer 4 have 4 stocks : ['COM7', 'MEGA', 'SPALI', 'WHA']
# custer 5 have 8 stocks : ['BCH', 'EPG', 'GUNKUL', 'IRPC', 'MBK', 'PLANB', 'TMB', 'TOP']
# custer 6 have 1 stocks : ['SCC']
# custer 7 have 2 stocks : ['GLOBAL', 'HMPRO']
# custer 8 have 10 stocks : ['AOT', 'AP', 'BBL', 'BH', 'CPALL', 'JMT', 'KCE', 'PSL', 'PTT', 'STEC']
# custer 9 have 1 stocks : ['JAS']
# custer 10 have 2 stocks : ['LH', 'MAJOR']
# custer 11 have 2 stocks : ['BTS', 'CPF']
# custer 12 have 8 stocks : ['CBG', 'EA', 'KTC', 'RS', 'STPI', 'TASCO', 'TRUE', 'VGI']
# custer 13 have 5 stocks : ['BDMS', 'GPSC', 'HANA', 'RATCH', 'TKN']
# custer 14 have 2 stocks : ['QH', 'SUPER']
# custer 15 have 9 stocks : ['BCP', 'BJC', 'CK', 'CKP', 'ERW', 'KKP', 'PTG', 'THAI', 'TISCO']
# custer 16 have 2 stocks : ['SPRC', 'TTW']
# custer 17 have 1 stocks : ['CENTEL']
# custer 18 have 5 stocks : ['GFPT', 'KBANK', 'KTB', 'SGP', 'STA']
# score of window: 1.990414667841249.
# --------------------------------------------------
# window 11:
# custer 1 have 5 stocks : ['CENTEL', 'KBANK', 'MBK', 'MEGA', 'PTG']
# custer 2 have 11 stocks : ['CHG', 'CK', 'CKP', 'EPG', 'GUNKUL', 'HMPRO', 'IRPC', 'IVL', 'JAS', 'JMT', 'TOP']
# custer 3 have 1 stocks : ['LH']
# custer 4 have 1 stocks : ['BEM']
# custer 5 have 5 stocks : ['ADVANC', 'AEONTS', 'BCH', 'BTS', 'EA']
# custer 6 have 1 stocks : ['SUPER']
# custer 7 have 20 stocks : ['BBL', 'BH', 'BJC', 'CBG', 'CPALL', 'CPN', 'DELTA', 'EGCO', 'ERW', 'ESSO', 'KCE', 'PTT', 'RS', 'SAWAD', 'SCB', 'SPRC', 'STA', 'TISCO', 'TKN', 'TMB']
# custer 8 have 4 stocks : ['BANPU', 'SPALI', 'THANI', 'TU']
# custer 9 have 5 stocks : ['KTB', 'ORI', 'PTTGC', 'SGP', 'THAI']
# custer 10 have 2 stocks : ['CPF', 'KTC']
# custer 11 have 1 stocks : ['QH']
# custer 12 have 1 stocks : ['TTW']
# custer 13 have 2 stocks : ['AMATA', 'GPSC']
# custer 14 have 17 stocks : ['BCP', 'BEC', 'DTAC', 'INTUCH', 'KKP', 'MINT', 'MTC', 'PLANB', 'PSL', 'PTTEP', 'RATCH', 'SCC', 'STEC', 'STPI', 'TASCO', 'TRUE', 'VGI']
# custer 15 have 5 stocks : ['AOT', 'AP', 'GFPT', 'HANA', 'TCAP']
# custer 16 have 5 stocks : ['BDMS', 'COM7', 'GLOBAL', 'MAJOR', 'WHA']
# score of window: 2.0795784412806078.
#
#
#
#
# ==================================================
# wavelet: sym17      davies_bouldin_score: 1.8489499570863037
# --------------------------------------------------
# window 1:
# custer 1 have 2 stocks : ['SPRC', 'THANI']
# custer 2 have 37 stocks : ['ADVANC', 'AP', 'BANPU', 'BBL', 'BCH', 'BJC', 'BTS', 'CBG', 'CENTEL', 'CHG', 'CK', 'CKP', 'COM7', 'CPF', 'CPN', 'DELTA', 'DTAC', 'GFPT', 'HMPRO', 'INTUCH', 'KBANK', 'KCE', 'KKP', 'KTB', 'KTC', 'MAJOR', 'MINT', 'ORI', 'PTT', 'PTTEP', 'PTTGC', 'SCB', 'SCC', 'SGP', 'SPALI', 'THAI', 'TU']
# custer 3 have 7 stocks : ['EPG', 'ERW', 'GUNKUL', 'JAS', 'SAWAD', 'STEC', 'TRUE']
# custer 4 have 3 stocks : ['BDMS', 'ESSO', 'MEGA']
# custer 5 have 1 stocks : ['STA']
# custer 6 have 4 stocks : ['AMATA', 'BEC', 'EA', 'SUPER']
# custer 7 have 1 stocks : ['LH']
# custer 8 have 4 stocks : ['CPALL', 'EGCO', 'TMB', 'TOP']
# custer 9 have 1 stocks : ['PLANB']
# custer 10 have 2 stocks : ['RS', 'STPI']
# custer 11 have 1 stocks : ['TTW']
# custer 12 have 1 stocks : ['JMT']
# custer 13 have 1 stocks : ['MBK']
# custer 14 have 1 stocks : ['TASCO']
# custer 15 have 8 stocks : ['AOT', 'GLOBAL', 'GPSC', 'HANA', 'PSL', 'TISCO', 'VGI', 'WHA']
# custer 16 have 4 stocks : ['AEONTS', 'IRPC', 'PTG', 'TCAP']
# custer 17 have 3 stocks : ['BCP', 'RATCH', 'TKN']
# custer 18 have 5 stocks : ['BEM', 'BH', 'IVL', 'MTC', 'QH']
# score of window: 1.6557720388783377.
# --------------------------------------------------
# window 2:
# custer 1 have 3 stocks : ['CENTEL', 'GLOBAL', 'PTG']
# custer 2 have 6 stocks : ['BCP', 'BDMS', 'EGCO', 'GPSC', 'PSL', 'TRUE']
# custer 3 have 15 stocks : ['AOT', 'AP', 'COM7', 'CPN', 'DELTA', 'GFPT', 'JMT', 'PTT', 'PTTEP', 'SCC', 'SPALI', 'STPI', 'TOP', 'VGI', 'WHA']
# custer 4 have 14 stocks : ['BANPU', 'BEM', 'BH', 'CBG', 'CKP', 'DTAC', 'EA', 'ERW', 'JAS', 'KKP', 'MEGA', 'ORI', 'TKN', 'TU']
# custer 5 have 1 stocks : ['INTUCH']
# custer 6 have 1 stocks : ['BTS']
# custer 7 have 7 stocks : ['AEONTS', 'CPF', 'HMPRO', 'IRPC', 'LH', 'SGP', 'SPRC']
# custer 8 have 4 stocks : ['CK', 'MAJOR', 'PLANB', 'QH']
# custer 9 have 1 stocks : ['TMB']
# custer 10 have 4 stocks : ['AMATA', 'CPALL', 'GUNKUL', 'SUPER']
# custer 11 have 6 stocks : ['BCH', 'CHG', 'IVL', 'KTB', 'MINT', 'TCAP']
# custer 12 have 4 stocks : ['ESSO', 'STEC', 'THANI', 'TTW']
# custer 13 have 1 stocks : ['TISCO']
# custer 14 have 1 stocks : ['HANA']
# custer 15 have 1 stocks : ['MBK']
# custer 16 have 14 stocks : ['ADVANC', 'BBL', 'BEC', 'BJC', 'EPG', 'KBANK', 'KCE', 'KTC', 'RS', 'SAWAD', 'SCB', 'STA', 'TASCO', 'THAI']
# custer 17 have 1 stocks : ['RATCH']
# custer 18 have 2 stocks : ['MTC', 'PTTGC']
# score of window: 1.83755027707391.
# --------------------------------------------------
# window 3:
# custer 1 have 32 stocks : ['AOT', 'BCH', 'BEM', 'CBG', 'COM7', 'CPF', 'DELTA', 'DTAC', 'EGCO', 'EPG', 'ESSO', 'GFPT', 'GLOBAL', 'GPSC', 'GUNKUL', 'HANA', 'JAS', 'KCE', 'KKP', 'MAJOR', 'MTC', 'ORI', 'PTTEP', 'PTTGC', 'SAWAD', 'SCC', 'STA', 'STPI', 'THANI', 'TISCO', 'TRUE', 'TU']
# custer 2 have 3 stocks : ['JMT', 'PTG', 'TASCO']
# custer 3 have 2 stocks : ['HMPRO', 'QH']
# custer 4 have 1 stocks : ['TMB']
# custer 5 have 2 stocks : ['IRPC', 'MINT']
# custer 6 have 1 stocks : ['RATCH']
# custer 7 have 2 stocks : ['BANPU', 'RS']
# custer 8 have 1 stocks : ['MBK']
# custer 9 have 9 stocks : ['AP', 'CENTEL', 'CPN', 'KTC', 'MEGA', 'PSL', 'PTT', 'SGP', 'SPRC']
# custer 10 have 1 stocks : ['BDMS']
# custer 11 have 3 stocks : ['BCP', 'BTS', 'WHA']
# custer 12 have 2 stocks : ['KTB', 'SCB']
# custer 13 have 2 stocks : ['AEONTS', 'TTW']
# custer 14 have 11 stocks : ['ADVANC', 'AMATA', 'BBL', 'BEC', 'BH', 'BJC', 'CPALL', 'KBANK', 'TCAP', 'THAI', 'TOP']
# custer 15 have 2 stocks : ['SPALI', 'TKN']
# custer 16 have 9 stocks : ['CHG', 'EA', 'ERW', 'IVL', 'LH', 'PLANB', 'STEC', 'SUPER', 'VGI']
# custer 17 have 2 stocks : ['CK', 'CKP']
# custer 18 have 1 stocks : ['INTUCH']
# score of window: 1.888272118380371.
# --------------------------------------------------
# window 4:
# custer 1 have 2 stocks : ['IVL', 'QH']
# custer 2 have 23 stocks : ['AEONTS', 'AOT', 'AP', 'BCP', 'BEC', 'BH', 'CBG', 'COM7', 'DELTA', 'DTAC', 'KCE', 'KKP', 'KTC', 'PSL', 'PTG', 'PTTEP', 'RS', 'SAWAD', 'STEC', 'THAI', 'THANI', 'TISCO', 'TOP']
# custer 3 have 2 stocks : ['GPSC', 'INTUCH']
# custer 4 have 3 stocks : ['GLOBAL', 'KTB', 'SUPER']
# custer 5 have 5 stocks : ['CPF', 'ESSO', 'MAJOR', 'SCC', 'TMB']
# custer 6 have 1 stocks : ['TTW']
# custer 7 have 5 stocks : ['BANPU', 'IRPC', 'PTT', 'TASCO', 'VGI']
# custer 8 have 10 stocks : ['AMATA', 'CENTEL', 'CHG', 'EPG', 'GFPT', 'GUNKUL', 'SPALI', 'TKN', 'TRUE', 'TU']
# custer 9 have 5 stocks : ['BDMS', 'CPALL', 'EGCO', 'LH', 'MTC']
# custer 10 have 1 stocks : ['MEGA']
# custer 11 have 2 stocks : ['HMPRO', 'MBK']
# custer 12 have 2 stocks : ['BJC', 'EA']
# custer 13 have 4 stocks : ['BCH', 'CKP', 'CPN', 'SPRC']
# custer 14 have 1 stocks : ['BTS']
# custer 15 have 7 stocks : ['ADVANC', 'BEM', 'ERW', 'JAS', 'KBANK', 'PTTGC', 'TCAP']
# custer 16 have 1 stocks : ['WHA']
# custer 17 have 8 stocks : ['BBL', 'HANA', 'JMT', 'MINT', 'ORI', 'PLANB', 'SCB', 'STA']
# custer 18 have 3 stocks : ['CK', 'SGP', 'STPI']
# custer 19 have 1 stocks : ['RATCH']
# score of window: 1.8996935595114703.
# --------------------------------------------------
# window 5:
# custer 1 have 3 stocks : ['BANPU', 'EGCO', 'VGI']
# custer 2 have 5 stocks : ['DTAC', 'GFPT', 'HMPRO', 'KTB', 'TISCO']
# custer 3 have 6 stocks : ['CPALL', 'PLANB', 'PTT', 'RATCH', 'SGP', 'TU']
# custer 4 have 1 stocks : ['BEM']
# ...
# custer 2 have 21 stocks : ['AMATA', 'BCH', 'BCP', 'BTS', 'CENTEL', 'CK', 'CKP', 'CPF', 'CPN', 'EPG', 'GLOBAL', 'GPSC', 'HMPRO', 'INTUCH', 'MBK', 'MINT', 'RATCH', 'SCB', 'SGP', 'SUPER', 'TASCO']
# custer 3 have 15 stocks : ['AEONTS', 'BDMS', 'COM7', 'EA', 'GFPT', 'IVL', 'JAS', 'KBANK', 'LH', 'MAJOR', 'MEGA', 'QH', 'TRUE', 'TTW', 'WHA']
# score of window: 3.8044410958204393.
# --------------------------------------------------
# window 5:
# custer 1 have 24 stocks : ['ADVANC', 'AEONTS', 'BBL', 'BEM', 'BJC', 'CHG', 'CPALL', 'GLOBAL', 'HMPRO', 'LH', 'MEGA', 'MINT', 'PLANB', 'PTTGC', 'QH', 'RATCH', 'SPALI', 'STA', 'STPI', 'TCAP', 'TRUE', 'TTW', 'TU', 'WHA']
# custer 2 have 16 stocks : ['BANPU', 'BCP', 'BTS', 'CK', 'CPF', 'EGCO', 'EPG', 'INTUCH', 'IRPC', 'IVL', 'JAS', 'KTB', 'MAJOR', 'PTT', 'SPRC', 'VGI']
# custer 3 have 46 stocks : ['AMATA', 'AOT', 'AP', 'BCH', 'BDMS', 'BEC', 'BH', 'CBG', 'CENTEL', 'CKP', 'COM7', 'CPN', 'DELTA', 'DTAC', 'EA', 'ERW', 'ESSO', 'GFPT', 'GPSC', 'GUNKUL', 'HANA', 'JMT', 'KBANK', 'KCE', 'KKP', 'KTC', 'MBK', 'MTC', 'ORI', 'PSL', 'PTG', 'PTTEP', 'RS', 'SAWAD', 'SCB', 'SCC', 'SGP', 'STEC', 'SUPER', 'TASCO', 'THAI', 'THANI', 'TISCO', 'TKN', 'TMB', 'TOP']
# score of window: 4.28671543210198.
# --------------------------------------------------
# window 6:
# custer 1 have 8 stocks : ['CKP', 'GUNKUL', 'HMPRO', 'KTB', 'MAJOR', 'MTC', 'STA', 'SUPER']
# custer 2 have 41 stocks : ['BANPU', 'BCH', 'BDMS', 'BEC', 'BH', 'CBG', 'COM7', 'CPALL', 'CPF', 'DELTA', 'DTAC', 'EA', 'EGCO', 'GLOBAL', 'HANA', 'IRPC', 'IVL', 'KBANK', 'KCE', 'KKP', 'KTC', 'MEGA', 'ORI', 'PLANB', 'PSL', 'PTG', 'PTT', 'PTTEP', 'PTTGC', 'RS', 'SAWAD', 'SCB', 'SPRC', 'STPI', 'TASCO', 'TKN', 'TOP', 'TTW', 'TU', 'VGI', 'WHA']
# custer 3 have 37 stocks : ['ADVANC', 'AEONTS', 'AMATA', 'AOT', 'AP', 'BBL', 'BCP', 'BEM', 'BJC', 'BTS', 'CENTEL', 'CHG', 'CK', 'CPN', 'EPG', 'ERW', 'ESSO', 'GFPT', 'GPSC', 'INTUCH', 'JAS', 'JMT', 'LH', 'MBK', 'MINT', 'QH', 'RATCH', 'SCC', 'SGP', 'SPALI', 'STEC', 'TCAP', 'THAI', 'THANI', 'TISCO', 'TMB', 'TRUE']
# score of window: 3.115513505297761.
# --------------------------------------------------
# window 7:
# custer 1 have 34 stocks : ['AEONTS', 'BANPU', 'BEC', 'BEM', 'BH', 'CBG', 'CENTEL', 'COM7', 'CPF', 'DELTA', 'EGCO', 'EPG', 'GLOBAL', 'GPSC', 'HANA', 'IVL', 'JAS', 'JMT', 'KBANK', 'KKP', 'MBK', 'MEGA', 'ORI', 'PTG', 'PTTEP', 'RS', 'SAWAD', 'STA', 'THAI', 'THANI', 'TISCO', 'TKN', 'TRUE', 'WHA']
# custer 2 have 31 stocks : ['ADVANC', 'AMATA', 'AOT', 'BBL', 'BCH', 'BDMS', 'BJC', 'CKP', 'CPN', 'DTAC', 'EA', 'ERW', 'ESSO', 'GUNKUL', 'HMPRO', 'KCE', 'KTC', 'MTC', 'PSL', 'PTT', 'PTTGC', 'SCB', 'SCC', 'SGP', 'SPALI', 'STEC', 'STPI', 'SUPER', 'TASCO', 'TOP', 'TU']
# custer 3 have 21 stocks : ['AP', 'BCP', 'BTS', 'CHG', 'CK', 'CPALL', 'GFPT', 'INTUCH', 'IRPC', 'KTB', 'LH', 'MAJOR', 'MINT', 'PLANB', 'QH', 'RATCH', 'SPRC', 'TCAP', 'TMB', 'TTW', 'VGI']
# score of window: 3.526205108664979.
# --------------------------------------------------
# window 8:
# custer 1 have 10 stocks : ['BCP', 'CHG', 'GUNKUL', 'JAS', 'KTB', 'QH', 'RATCH', 'SCC', 'SUPER', 'TTW']
# custer 2 have 51 stocks : ['ADVANC', 'AEONTS', 'AMATA', 'AOT', 'AP', 'BANPU', 'BCH', 'BDMS', 'BEC', 'BJC', 'CBG', 'CENTEL', 'CKP', 'COM7', 'CPALL', 'CPF', 'CPN', 'DTAC', 'EA', 'EGCO', 'ERW', 'ESSO', 'GFPT', 'GLOBAL', 'GPSC', 'HANA', 'IVL', 'JMT', 'KCE', 'KTC', 'MINT', 'MTC', 'ORI', 'PLANB', 'PTG', 'PTT', 'PTTEP', 'PTTGC', 'RS', 'SAWAD', 'SCB', 'SGP', 'SPALI', 'SPRC', 'STA', 'STEC', 'TASCO', 'THAI', 'TKN', 'TOP', 'WHA']
# custer 3 have 25 stocks : ['BBL', 'BEM', 'BH', 'BTS', 'CK', 'DELTA', 'EPG', 'HMPRO', 'INTUCH', 'IRPC', 'KBANK', 'KKP', 'LH', 'MAJOR', 'MBK', 'MEGA', 'PSL', 'STPI', 'TCAP', 'THANI', 'TISCO', 'TMB', 'TRUE', 'TU', 'VGI']
# score of window: 4.435815746422222.
# --------------------------------------------------
# window 9:
# custer 1 have 17 stocks : ['BJC', 'BTS', 'CHG', 'CKP', 'DELTA', 'ERW', 'GLOBAL', 'IRPC', 'JAS', 'KTB', 'MEGA', 'QH', 'SPRC', 'SUPER', 'TOP', 'TTW', 'WHA']
# custer 2 have 57 stocks : ['ADVANC', 'AEONTS', 'AMATA', 'AOT', 'AP', 'BANPU', 'BBL', 'BDMS', 'BEC', 'BEM', 'BH', 'CBG', 'CENTEL', 'COM7', 'CPALL', 'CPN', 'DTAC', 'EA', 'EGCO', 'EPG', 'ESSO', 'GFPT', 'GPSC', 'GUNKUL', 'HANA', 'HMPRO', 'INTUCH', 'IVL', 'JMT', 'KBANK', 'KCE', 'KKP', 'KTC', 'MBK', 'MINT', 'MTC', 'ORI', 'PSL', 'PTTGC', 'RATCH', 'RS', 'SAWAD', 'SCB', 'SCC', 'SGP', 'SPALI', 'STA', 'STEC', 'STPI', 'TASCO', 'TCAP', 'THAI', 'THANI', 'TISCO', 'TKN', 'TU', 'VGI']
# custer 3 have 12 stocks : ['BCH', 'BCP', 'CK', 'CPF', 'LH', 'MAJOR', 'PLANB', 'PTG', 'PTT', 'PTTEP', 'TMB', 'TRUE']
# score of window: 4.32535701686097.
# --------------------------------------------------
# window 10:
# custer 1 have 64 stocks : ['ADVANC', 'AEONTS', 'AMATA', 'AOT', 'AP', 'BANPU', 'BBL', 'BDMS', 'BEC', 'BH', 'CBG', 'CKP', 'COM7', 'CPALL', 'CPN', 'DELTA', 'DTAC', 'EA', 'EGCO', 'EPG', 'ESSO', 'GFPT', 'GPSC', 'GUNKUL', 'HANA', 'INTUCH', 'IRPC', 'IVL', 'JMT', 'KBANK', 'KCE', 'KKP', 'KTB', 'KTC', 'MAJOR', 'MBK', 'MEGA', 'MINT', 'MTC', 'ORI', 'PLANB', 'PSL', 'PTT', 'PTTEP', 'PTTGC', 'RATCH', 'RS', 'SAWAD', 'SCB', 'SGP', 'SPALI', 'STA', 'STEC', 'STPI', 'TASCO', 'TCAP', 'THAI', 'THANI', 'TISCO', 'TKN', 'TMB', 'TOP', 'TU', 'WHA']
# custer 2 have 6 stocks : ['BCP', 'CPF', 'QH', 'SCC', 'SPRC', 'SUPER']
# custer 3 have 16 stocks : ['BCH', 'BEM', 'BJC', 'BTS', 'CENTEL', 'CHG', 'CK', 'ERW', 'GLOBAL', 'HMPRO', 'JAS', 'LH', 'PTG', 'TRUE', 'TTW', 'VGI']
# score of window: 3.9616200307442986.
# --------------------------------------------------
# window 11:
# custer 1 have 50 stocks : ['ADVANC', 'AP', 'BBL', 'BCP', 'BEC', 'BH', 'BJC', 'CBG', 'CK', 'CKP', 'CPALL', 'CPN', 'DELTA', 'DTAC', 'EGCO', 'EPG', 'ERW', 'ESSO', 'GPSC', 'HANA', 'HMPRO', 'INTUCH', 'IRPC', 'JAS', 'JMT', 'KBANK', 'KCE', 'MBK', 'MINT', 'PLANB', 'PTG', 'PTT', 'PTTEP', 'PTTGC', 'RATCH', 'SAWAD', 'SCB', 'SCC', 'SPRC', 'STA', 'STEC', 'STPI', 'TASCO', 'TCAP', 'THAI', 'TKN', 'TMB', 'TOP', 'TRUE', 'VGI']
# custer 2 have 15 stocks : ['AEONTS', 'AOT', 'BCH', 'BDMS', 'BTS', 'CHG', 'CPF', 'EA', 'GLOBAL', 'IVL', 'KTC', 'LH', 'MAJOR', 'MTC', 'WHA']
# custer 3 have 21 stocks : ['AMATA', 'BANPU', 'BEM', 'CENTEL', 'COM7', 'GFPT', 'GUNKUL', 'KKP', 'KTB', 'MEGA', 'ORI', 'PSL', 'QH', 'RS', 'SGP', 'SPALI', 'SUPER', 'THANI', 'TISCO', 'TTW', 'TU']
# score of window: 4.422675984508323.
#
#
#
#
# ==================================================
# wavelet: sym20      calinski_harabasz_score: 3.9280862722854413
# --------------------------------------------------
# window 1:
# custer 1 have 16 stocks : ['BEM', 'CPALL', 'EGCO', 'GUNKUL', 'HANA', 'JMT', 'LH', 'MTC', 'PLANB', 'QH', 'STA', 'TASCO', 'THANI', 'TMB', 'TOP', 'TTW']
# custer 2 have 6 stocks : ['BDMS', 'ESSO', 'MBK', 'MEGA', 'RS', 'TRUE']
# custer 3 have 64 stocks : ['ADVANC', 'AEONTS', 'AMATA', 'AOT', 'AP', 'BANPU', 'BBL', 'BCH', 'BCP', 'BEC', 'BH', 'BJC', 'BTS', 'CBG', 'CENTEL', 'CHG', 'CK', 'CKP', 'COM7', 'CPF', 'CPN', 'DELTA', 'DTAC', 'EA', 'EPG', 'ERW', 'GFPT', 'GLOBAL', 'GPSC', 'HMPRO', 'INTUCH', 'IRPC', 'IVL', 'JAS', 'KBANK', 'KCE', 'KKP', 'KTB', 'KTC', 'MAJOR', 'MINT', 'ORI', 'PSL', 'PTG', 'PTT', 'PTTEP', 'PTTGC', 'RATCH', 'SAWAD', 'SCB', 'SCC', 'SGP', 'SPALI', 'SPRC', 'STEC', 'STPI', 'SUPER', 'TCAP', 'THAI', 'TISCO', 'TKN', 'TU', 'VGI', 'WHA']
# score of window: 3.8348797399012686.
# --------------------------------------------------
# window 2:
# custer 1 have 9 stocks : ['AMATA', 'CPALL', 'HANA', 'INTUCH', 'IRPC', 'MBK', 'SGP', 'TISCO', 'TMB']
# custer 2 have 67 stocks : ['ADVANC', 'AOT', 'BANPU', 'BBL', 'BCH', 'BCP', 'BDMS', 'BEC', 'BEM', 'BH', 'BJC', 'CBG', 'CENTEL', 'CHG', 'CKP', 'COM7', 'CPF', 'CPN', 'DELTA', 'DTAC', 'EA', 'EGCO', 'EPG', 'ERW', 'ESSO', 'GFPT', 'GLOBAL', 'GUNKUL', 'HMPRO', 'IVL', 'JAS', 'JMT', 'KCE', 'KKP', 'KTB', 'KTC', 'LH', 'MEGA', 'MINT', 'MTC', 'ORI', 'PSL', 'PTG', 'PTT', 'PTTEP', 'PTTGC', 'RATCH', 'RS', 'SAWAD', 'SCB', 'SCC', 'SPALI', 'SPRC', 'STA', 'STEC', 'STPI', 'SUPER', 'TASCO', 'TCAP', 'THAI', 'THANI', 'TKN', 'TOP', 'TRUE', 'TU', 'VGI', 'WHA']
# custer 3 have 10 stocks : ['AEONTS', 'AP', 'BTS', 'CK', 'GPSC', 'KBANK', 'MAJOR', 'PLANB', 'QH', 'TTW']
# score of window: 4.201902811611337.
# --------------------------------------------------
# window 3:
# custer 1 have 44 stocks : ['AOT', 'AP', 'BBL', 'BCH', 'BEC', 'BH', 'BJC', 'CBG', 'CHG', 'CPALL', 'DELTA', 'DTAC', 'EGCO', 'EPG', 'ESSO', 'GUNKUL', 'HANA', 'HMPRO', 'JAS', 'JMT', 'KBANK', 'KKP', 'KTC', 'MAJOR', 'MTC', 'PSL', 'PTT', 'PTTGC', 'SCB', 'SCC', 'SPALI', 'SPRC', 'STA', 'STEC', 'STPI', 'SUPER', 'TASCO', 'THAI', 'TISCO', 'TKN', 'TOP', 'TU', 'VGI', 'WHA']
# custer 2 have 21 stocks : ['ADVANC', 'BANPU', 'BDMS', 'BEM', 'COM7', 'CPF', 'EA', 'ERW', 'GFPT', 'GLOBAL', 'GPSC', 'IVL', 'KCE', 'KTB', 'MEGA', 'ORI', 'PTTEP', 'RS', 'SAWAD', 'SGP', 'THANI']
# custer 3 have 21 stocks : ['AEONTS', 'AMATA', 'BCP', 'BTS', 'CENTEL', 'CK', 'CKP', 'CPN', 'INTUCH', 'IRPC', 'LH', 'MBK', 'MINT', 'PLANB', 'PTG', 'QH', 'RATCH', 'TCAP', 'TMB', 'TRUE', 'TTW']
# score of window: 3.830259347569298.
# --------------------------------------------------
# window 4:
# custer 1 have 24 stocks : ['AEONTS', 'BBL', 'BCP', 'CHG', 'CKP', 'COM7', 'CPF', 'EA', 'EPG', 'ESSO', 'GFPT', 'GLOBAL', 'GPSC', 'JAS', 'KBANK', 'KTB', 'LH', 'MEGA', 'QH', 'RATCH', 'SUPER', 'TRUE', 'TTW', 'WHA']
# custer 2 have 45 stocks : ['ADVANC', 'AMATA', 'AOT', 'AP', 'BDMS', 'BEC', 'BH', 'CBG', 'CENTEL', 'CPALL', 'DELTA', 'DTAC', 'EGCO', 'ERW', 'GUNKUL', 'HANA', 'IRPC', 'JMT', 'KCE', 'KKP', 'KTC', 'MAJOR', 'MINT', 'MTC', 'ORI', 'PLANB', 'PSL', 'PTG', 'PTTEP', 'PTTGC', 'RS', 'SAWAD', 'SCB', 'SCC', 'SPALI', 'STA', 'STEC', 'STPI', 'TCAP', 'THAI', 'THANI', 'TISCO', 'TKN', 'TOP', 'TU']
# custer 3 have 17 stocks : ['BANPU', 'BCH', 'BEM', 'BJC', 'BTS', 'CK', 'CPN', 'HMPRO', 'INTUCH', 'IVL', 'MBK', 'PTT', 'SGP', 'SPRC', 'TASCO', 'TMB', 'VGI']
# score of window: 3.5570443942090875.
# --------------------------------------------------
# window 5:
# custer 1 have 9 stocks : ['BANPU', 'BEM', 'BTS', 'CK', 'CPALL', 'INTUCH', 'IRPC', 'SPRC', 'VGI']
# custer 2 have 61 stocks : ['ADVANC', 'AEONTS', 'AMATA', 'AOT', 'AP', 'BBL', 'BCH', 'BDMS', 'BEC', 'BH', 'BJC', 'CBG', 'CENTEL', 'CHG', 'CKP', 'COM7', 'CPF', 'CPN', 'DELTA', 'DTAC', 'EA', 'ERW', 'ESSO', 'GFPT', 'GLOBAL', 'GPSC', 'GUNKUL', 'HANA', 'HMPRO', 'IVL', 'JMT', 'KBANK', 'KCE', 'KTC', 'MAJOR', 'MBK', 'MEGA', 'MTC', 'ORI', 'PLANB', 'PSL', 'PTG', 'PTT', 'PTTEP', 'PTTGC', 'RATCH', 'RS', 'SAWAD', 'SCC', 'SGP', 'SPALI', 'STPI', 'SUPER', 'TASCO', 'THAI', 'THANI', 'TISCO', 'TKN', 'TMB', 'TOP', 'WHA']
# custer 3 have 16 stocks : ['BCP', 'EGCO', 'EPG', 'JAS', 'KKP', 'KTB', 'LH', 'MINT', 'QH', 'SCB', 'STA', 'STEC', 'TCAP', 'TRUE', 'TTW', 'TU']
# score of window: 4.272044823714251.
# --------------------------------------------------
# window 6:
# custer 1 have 17 stocks : ['AP', 'BDMS', 'CK', 'CPF', 'EPG', 'HMPRO', 'KTB', 'MAJOR', 'MINT', 'MTC', 'RATCH', 'SPALI', 'STA', 'SUPER', 'TCAP', 'TKN', 'TRUE']
# custer 2 have 31 stocks : ['AMATA', 'AOT', 'BANPU', 'BBL', 'BCP', 'BEM', 'BH', 'BTS', 'CKP', 'DELTA', 'DTAC', 'EA', 'EGCO', 'GFPT', 'GPSC', 'INTUCH', 'IVL', 'JAS', 'KBANK', 'KKP', 'PLANB', 'PSL', 'PTT', 'PTTEP', 'QH', 'SCB', 'SPRC', 'STPI', 'THAI', 'TISCO', 'TTW']
# custer 3 have 38 stocks : ['ADVANC', 'AEONTS', 'BCH', 'BEC', 'BJC', 'CBG', 'CENTEL', 'CHG', 'COM7', 'CPALL', 'CPN', 'ERW', 'ESSO', 'GLOBAL', 'GUNKUL', 'HANA', 'IRPC', 'JMT', 'KCE', 'KTC', 'LH', 'MBK', 'MEGA', 'ORI', 'PTG', 'PTTGC', 'RS', 'SAWAD', 'SCC', 'SGP', 'STEC', 'TASCO', 'THANI', 'TMB', 'TOP', 'TU', 'VGI', 'WHA']
# score of window: 3.0398071731069707.
# --------------------------------------------------
# window 7:
# custer 1 have 13 stocks : ['BCP', 'BDMS', 'BJC', 'EGCO', 'GUNKUL', 'JAS', 'KKP', 'ORI', 'PSL', 'RATCH', 'SPRC', 'SUPER', 'TKN']
# custer 2 have 58 stocks : ['ADVANC', 'AEONTS', 'AMATA', 'AP', 'BANPU', 'BBL', 'BEC', 'BH', 'CBG', 'CENTEL', 'CHG', 'CKP', 'COM7', 'CPALL', 'CPF', 'CPN', 'DELTA', 'DTAC', 'EA', 'EPG', 'ERW', 'ESSO', 'GFPT', 'GLOBAL', 'GPSC', 'IRPC', 'IVL', 'JMT', 'KBANK', 'KCE', 'KTB', 'KTC', 'MBK', 'MINT', 'MTC', 'PLANB', 'PTG', 'PTT', 'PTTEP', 'PTTGC', 'QH', 'RS', 'SAWAD', 'SCB', 'SCC', 'SGP', 'SPALI', 'STA', 'STEC', 'STPI', 'TASCO', 'TCAP', 'THAI', 'TISCO', 'TOP', 'TTW', 'TU', 'WHA']
# custer 3 have 15 stocks : ['AOT', 'BCH', 'BEM', 'BTS', 'CK', 'HANA', 'HMPRO', 'INTUCH', 'LH', 'MAJOR', 'MEGA', 'THANI', 'TMB', 'TRUE', 'VGI']
# score of window: 3.469546723068012.
# --------------------------------------------------
# window 8:
# custer 1 have 40 stocks : ['ADVANC', 'AEONTS', 'AMATA', 'AOT', 'BCH', 'BEC', 'CBG', 'CENTEL', 'CKP', 'COM7', 'CPALL', 'EA', 'ERW', 'ESSO', 'GFPT', 'GLOBAL', 'GPSC', 'HANA', 'IVL', 'JMT', 'KCE', 'KTC', 'MINT', 'MTC', 'PLANB', 'PTG', 'PTT', 'PTTEP', 'PTTGC', 'RS', 'SAWAD', 'SCB', 'SPALI', 'STEC', 'TASCO', 'TCAP', 'TKN', 'TOP', 'TRUE', 'WHA']
# custer 2 have 16 stocks : ['BCP', 'BDMS', 'BTS', 'CHG', 'CK', 'CPF', 'IRPC', 'JAS', 'KTB', 'QH', 'RATCH', 'SCC', 'STA', 'SUPER', 'TMB', 'TTW']
# custer 3 have 30 stocks : ['AP', 'BANPU', 'BBL', 'BEM', 'BH', 'BJC', 'CPN', 'DELTA', 'DTAC', 'EGCO', 'EPG', 'GUNKUL', 'HMPRO', 'INTUCH', 'KBANK', 'KKP', 'LH', 'MAJOR', 'MBK', 'MEGA', 'ORI', 'PSL', 'SGP', 'SPRC', 'STPI', 'THAI', 'THANI', 'TISCO', 'TU', 'VGI']
# score of window: 4.44564090898625.
# --------------------------------------------------
# window 9:
# custer 1 have 49 stocks : ['ADVANC', 'AEONTS', 'AMATA', 'BANPU', 'BBL', 'BDMS', 'BEC', 'BEM', 'BH', 'CBG', 'CENTEL', 'COM7', 'DTAC', 'EA', 'EGCO', 'EPG', 'ESSO', 'GFPT', 'GPSC', 'GUNKUL', 'HANA', 'INTUCH', 'IVL', 'JMT', 'KBANK', 'KCE', 'KKP', 'KTC', 'ORI', 'PLANB', 'PSL', 'PTG', 'PTT', 'PTTEP', 'PTTGC', 'RATCH', 'SAWAD', 'SCB', 'SCC', 'SGP', 'STA', 'STEC', 'STPI', 'TCAP', 'THANI', 'TKN', 'TU', 'VGI', 'WHA']
# custer 2 have 23 stocks : ['AOT', 'AP', 'BCH', 'BCP', 'BJC', 'BTS', 'CK', 'CKP', 'CPALL', 'CPN', 'HMPRO', 'JAS', 'MBK', 'MEGA', 'MINT', 'MTC', 'RS', 'SPALI', 'TASCO', 'THAI', 'TISCO', 'TRUE', 'TTW']
# custer 3 have 14 stocks : ['CHG', 'CPF', 'DELTA', 'ERW', 'GLOBAL', 'IRPC', 'KTB', 'LH', 'MAJOR', 'QH', 'SPRC', 'SUPER', 'TMB', 'TOP']
# score of window: 4.327481398643666.
# --------------------------------------------------
# window 10:
# custer 1 have 46 stocks : ['ADVANC', 'AEONTS', 'AMATA', 'BANPU', 'BDMS', 'BEC', 'BH', 'CBG', 'COM7', 'CPALL', 'CPN', 'DELTA', 'DTAC', 'EA', 'EGCO', 'EPG', 'ESSO', 'GFPT', 'GUNKUL', 'HMPRO', 'INTUCH', 'JMT', 'KBANK', 'KCE', 'KKP', 'KTC', 'MAJOR', 'MBK', 'MEGA', 'MINT', 'ORI', 'PSL', 'PTT', 'PTTEP', 'PTTGC', 'RATCH', 'RS', 'SAWAD', 'SGP', 'STA', 'STPI', 'TASCO', 'THAI', 'THANI', 'TKN', 'TOP']
# custer 2 have 19 stocks : ['BCH', 'BCP', 'BEM', 'BTS', 'CENTEL', 'CK', 'CPF', 'GLOBAL', 'JAS', 'KTB', 'LH', 'QH', 'SCC', 'SPRC', 'STEC', 'SUPER', 'TCAP', 'TRUE', 'VGI']
# custer 3 have 21 stocks : ['AOT', 'AP', 'BBL', 'BJC', 'CHG', 'CKP', 'ERW', 'GPSC', 'HANA', 'IRPC', 'IVL', 'MTC', 'PLANB', 'PTG', 'SCB', 'SPALI', 'TISCO', 'TMB', 'TTW', 'TU', 'WHA']
# score of window: 4.1025479215006095.
# --------------------------------------------------
# window 11:
# custer 1 have 18 stocks : ['BDMS', 'BEM', 'BTS', 'CENTEL', 'ERW', 'GFPT', 'GUNKUL', 'JAS', 'KKP', 'KTB', 'LH', 'MINT', 'PTTGC', 'QH', 'SUPER', 'THANI', 'TTW', 'TU']
# custer 2 have 22 stocks : ['AOT', 'AP', 'BANPU', 'BCH', 'BCP', 'CHG', 'CPF', 'EA', 'GLOBAL', 'HANA', 'HMPRO', 'IRPC', 'IVL', 'KTC', 'MAJOR', 'MTC', 'RATCH', 'SCC', 'STEC', 'STPI', 'TCAP', 'WHA']
# custer 3 have 46 stocks : ['ADVANC', 'AEONTS', 'AMATA', 'BBL', 'BEC', 'BH', 'BJC', 'CBG', 'CK', 'CKP', 'COM7', 'CPALL', 'CPN', 'DELTA', 'DTAC', 'EGCO', 'EPG', 'ESSO', 'GPSC', 'INTUCH', 'JMT', 'KBANK', 'KCE', 'MBK', 'MEGA', 'ORI', 'PLANB', 'PSL', 'PTG', 'PTT', 'PTTEP', 'RS', 'SAWAD', 'SCB', 'SGP', 'SPALI', 'SPRC', 'STA', 'TASCO', 'THAI', 'TISCO', 'TKN', 'TMB', 'TOP', 'TRUE', 'VGI']
# score of window: 4.127793752829104.

# %%
rank_table = {}

for wavelet_name in wavelet_names: 
    rank_table[wavelet_name] = []

for cal_score_obj in cal_scores: 
    score_name = cal_score_obj['name'] 
    score_optimize = cal_score_obj['optimize']
    avg_scores = [(wavelet_name, wavelet_table[wavelet_name]['avg_' + score_name]) for wavelet_name in wavelet_names] 
    sorted_wavelet = [score_tuple[0] for score_tuple in sorted(avg_scores, key=lambda x:x[1], reverse=score_optimize==max)] 
    for index, wavelet_name in enumerate(sorted_wavelet):
        rank_table[wavelet_name].append(index) 

rank_list = [(wavelet_name, sum(rank_table[wavelet_name])) for wavelet_name in rank_table.keys()]
top_wavelet = sorted(rank_list, key=lambda x:x[1])[0][0]

# %%
top_wavelet
# Out:
# 'rbio3.7'

# %%
new_matrix = {}
n_windows = len(wavelet_table[wavelet_names[0]]['windows'] )
n_stocks = len(stock_list_filtered)

for cal_score_obj_1 in cal_scores:
    score_name_1 = cal_score_obj_1['name']
    new_matrix[score_name_1] = {}
    for cal_score_obj_2 in cal_scores:
        score_name_2 = cal_score_obj_2['name']
        new_matrix[score_name_1][score_name_2] = np.full((n_stocks, n_stocks), 0, dtype=float)
        np.fill_diagonal(new_matrix[score_name_1][score_name_2], 1)

for cal_score_obj_1 in cal_scores:
    score_name_1 = cal_score_obj_1['name']
    for cal_score_obj_2 in cal_scores:
        score_name_2 = cal_score_obj_2['name']
        windows = wavelet_table[top_wavelet]['windows']
        for window in windows: 
            window = window[score_name_1] 
            for label in window['labels']: 
                for pair in combinations(label, 2):
                    index_i = stock_list_filtered.index(pair[0])
                    index_j = stock_list_filtered.index(pair[1]) 
                    new_matrix[score_name_1][score_name_2][index_i][index_j] += 1 / n_windows
                    new_matrix[score_name_1][score_name_2][index_j][index_i] += 1 / n_windows

# %%
all_windows = {}

for cal_score_obj_1 in cal_scores:
    score_name_1 = cal_score_obj_1['name']
    all_windows[score_name_1] = {}
    for cal_score_obj_2 in cal_scores:
        score_name_2 = cal_score_obj_2['name']
        labels, score = k_mean(new_matrix[score_name_1][score_name_2], cal_score_obj_2)
        all_windows[score_name_1][score_name_2] = {
            'labels': labels,
            'score': score
        }

# %%
print('wavelet: {:}.\n\n'.format(top_wavelet))

for cal_score_obj_1 in cal_scores:
    score_name_1 = cal_score_obj_1['name']
    print('='*50)
    print(score_name_1)
    for cal_score_obj_2 in cal_scores:
        score_name_2 = cal_score_obj_2['name']
        all_window = all_windows[score_name_1][score_name_2]
        print('-'*50)
        print('score method: {:10}, score: {:}'.format(score_name_2, all_window['score']))
    print('\n')
# Out:
# wavelet: rbio3.7.
#
#
# ==================================================
# silhouette_score
# --------------------------------------------------
# score method: silhouette_score, score: 0.19309050316931406
# --------------------------------------------------
# score method: davies_bouldin_score, score: 1.3384981732838395
# --------------------------------------------------
# score method: calinski_harabasz_score, score: 20.539115167256348
#
#
# ==================================================
# davies_bouldin_score
# --------------------------------------------------
# score method: silhouette_score, score: 0.07884168664647657
# --------------------------------------------------
# score method: davies_bouldin_score, score: 1.9392318079751794
# --------------------------------------------------
# score method: calinski_harabasz_score, score: 8.992466994806191
#
#
# ==================================================
# calinski_harabasz_score
# --------------------------------------------------
# score method: silhouette_score, score: 0.1583507141462027
# --------------------------------------------------
# score method: davies_bouldin_score, score: 1.2901333668687178
# --------------------------------------------------
# score method: calinski_harabasz_score, score: 21.849953893408557

# %%
print('wavelet: {:}.\n\n'.format(top_wavelet))

for cal_score_obj_1 in cal_scores:
    score_name_1 = cal_score_obj_1['name']
    print('='*50)
    print(score_name_1)
    for cal_score_obj_2 in cal_scores:
        score_name_2 = cal_score_obj_2['name']
        all_window = all_windows[score_name_1][score_name_2]
        print('-'*50)
        print('score method: {:10}, score: {:}'.format(score_name_2, all_window['score']))
        for i, label in enumerate(all_window['labels']): 
            print('custer {:} have {:} stocks : {:}'.format(i+1, len(label), label))
    print('\n')
# Out:
# wavelet: rbio3.7.
#
#
# ==================================================
# silhouette_score
# --------------------------------------------------
# score method: silhouette_score, score: 0.19309050316931406
# custer 1 have 4 stocks : ['BBL', 'ESSO', 'SCC', 'SPALI']
# custer 2 have 5 stocks : ['AP', 'COM7', 'GFPT', 'MEGA', 'TCAP']
# custer 3 have 4 stocks : ['CHG', 'JAS', 'KTB', 'SUPER']
# custer 4 have 8 stocks : ['CPALL', 'EGCO', 'GPSC', 'HANA', 'MTC', 'RS', 'THANI', 'WHA']
# custer 5 have 8 stocks : ['ADVANC', 'BEC', 'BH', 'CBG', 'KCE', 'ORI', 'PTTGC', 'SAWAD']
# custer 6 have 5 stocks : ['BEM', 'BTS', 'LH', 'QH', 'TTW']
# custer 7 have 3 stocks : ['EA', 'MBK', 'PLANB']
# custer 8 have 3 stocks : ['BANPU', 'HMPRO', 'VGI']
# custer 9 have 9 stocks : ['AEONTS', 'AMATA', 'AOT', 'CPN', 'PSL', 'SCB', 'SGP', 'STPI', 'TKN']
# custer 10 have 4 stocks : ['DTAC', 'EPG', 'JMT', 'STA']
# custer 11 have 4 stocks : ['CK', 'CKP', 'CPF', 'MINT']
# custer 12 have 2 stocks : ['MAJOR', 'THAI']
# custer 13 have 6 stocks : ['BCH', 'KBANK', 'KTC', 'PTT', 'PTTEP', 'TASCO']
# custer 14 have 6 stocks : ['BCP', 'DELTA', 'ERW', 'GLOBAL', 'PTG', 'TOP']
# custer 15 have 3 stocks : ['BJC', 'KKP', 'SPRC']
# custer 16 have 3 stocks : ['INTUCH', 'RATCH', 'TRUE']
# custer 17 have 3 stocks : ['IRPC', 'TISCO', 'TMB']
# custer 18 have 3 stocks : ['CENTEL', 'IVL', 'TU']
# custer 19 have 3 stocks : ['BDMS', 'GUNKUL', 'STEC']
# --------------------------------------------------
# score method: davies_bouldin_score, score: 1.3384981732838395
# custer 1 have 4 stocks : ['AEONTS', 'CENTEL', 'EA', 'MEGA']
# custer 2 have 5 stocks : ['AOT', 'AP', 'COM7', 'EPG', 'GFPT']
# custer 3 have 3 stocks : ['BANPU', 'HMPRO', 'VGI']
# custer 4 have 8 stocks : ['BCH', 'BEC', 'KBANK', 'KTC', 'PTT', 'PTTEP', 'TASCO', 'TCAP']
# custer 5 have 5 stocks : ['CK', 'CKP', 'CPF', 'IRPC', 'MINT']
# custer 6 have 8 stocks : ['CPALL', 'EGCO', 'GPSC', 'HANA', 'MTC', 'RS', 'THANI', 'WHA']
# custer 7 have 5 stocks : ['CHG', 'JAS', 'KTB', 'SPRC', 'SUPER']
# custer 8 have 4 stocks : ['BDMS', 'GLOBAL', 'TISCO', 'TMB']
# custer 9 have 5 stocks : ['BCP', 'DELTA', 'ERW', 'PTG', 'TOP']
# custer 10 have 7 stocks : ['ADVANC', 'BH', 'CBG', 'KCE', 'ORI', 'PTTGC', 'SAWAD']
# custer 11 have 4 stocks : ['GUNKUL', 'JMT', 'MAJOR', 'STEC']
# custer 12 have 3 stocks : ['BEM', 'LH', 'THAI']
# custer 13 have 3 stocks : ['BTS', 'QH', 'TTW']
# custer 14 have 8 stocks : ['AMATA', 'CPN', 'PLANB', 'PSL', 'SCB', 'SGP', 'STPI', 'TKN']
# custer 15 have 3 stocks : ['BJC', 'IVL', 'TU']
# custer 16 have 7 stocks : ['BBL', 'DTAC', 'ESSO', 'KKP', 'SCC', 'SPALI', 'STA']
# custer 17 have 4 stocks : ['INTUCH', 'MBK', 'RATCH', 'TRUE']
# --------------------------------------------------
# score method: calinski_harabasz_score, score: 20.539115167256348
# custer 1 have 31 stocks : ['BANPU', 'BCP', 'BDMS', 'BEM', 'BJC', 'BTS', 'CHG', 'CK', 'CKP', 'CPF', 'HMPRO', 'INTUCH', 'IRPC', 'IVL', 'JAS', 'KTB', 'LH', 'MAJOR', 'MINT', 'QH', 'RATCH', 'SPALI', 'SPRC', 'SUPER', 'THAI', 'TISCO', 'TMB', 'TRUE', 'TTW', 'TU', 'VGI']
# custer 2 have 23 stocks : ['AP', 'BBL', 'CPALL', 'DELTA', 'DTAC', 'EA', 'EGCO', 'ERW', 'GLOBAL', 'GPSC', 'GUNKUL', 'HANA', 'JMT', 'KKP', 'MBK', 'MTC', 'PTG', 'RS', 'STA', 'STEC', 'THANI', 'TOP', 'WHA']
# custer 3 have 32 stocks : ['ADVANC', 'AEONTS', 'AMATA', 'AOT', 'BCH', 'BEC', 'BH', 'CBG', 'CENTEL', 'COM7', 'CPN', 'EPG', 'ESSO', 'GFPT', 'KBANK', 'KCE', 'KTC', 'MEGA', 'ORI', 'PLANB', 'PSL', 'PTT', 'PTTEP', 'PTTGC', 'SAWAD', 'SCB', 'SCC', 'SGP', 'STPI', 'TASCO', 'TCAP', 'TKN']
#
#
# ==================================================
# davies_bouldin_score
# --------------------------------------------------
# score method: silhouette_score, score: 0.07884168664647657
# custer 1 have 33 stocks : ['AMATA', 'BANPU', 'BCP', 'BDMS', 'BEM', 'BTS', 'CK', 'CPALL', 'CPF', 'GPSC', 'GUNKUL', 'HANA', 'HMPRO', 'INTUCH', 'JAS', 'LH', 'MAJOR', 'MINT', 'PLANB', 'QH', 'RATCH', 'STEC', 'SUPER', 'TASCO', 'THAI', 'THANI', 'TISCO', 'TKN', 'TMB', 'TRUE', 'TTW', 'VGI', 'WHA']
# custer 2 have 37 stocks : ['AEONTS', 'BBL', 'BCH', 'BEC', 'BH', 'BJC', 'CBG', 'CENTEL', 'COM7', 'DELTA', 'DTAC', 'EA', 'EPG', 'ESSO', 'GFPT', 'IVL', 'KBANK', 'KCE', 'KKP', 'KTB', 'KTC', 'MBK', 'MEGA', 'ORI', 'PSL', 'PTG', 'PTT', 'PTTEP', 'PTTGC', 'SAWAD', 'SCB', 'SCC', 'SGP', 'SPRC', 'STA', 'STPI', 'TU']
# custer 3 have 16 stocks : ['ADVANC', 'AOT', 'AP', 'CHG', 'CKP', 'CPN', 'EGCO', 'ERW', 'GLOBAL', 'IRPC', 'JMT', 'MTC', 'RS', 'SPALI', 'TCAP', 'TOP']
# --------------------------------------------------
# score method: davies_bouldin_score, score: 1.9392318079751794
# custer 1 have 6 stocks : ['BBL', 'BEC', 'BH', 'DELTA', 'KCE', 'SGP']
# custer 2 have 4 stocks : ['CHG', 'EGCO', 'ERW', 'TOP']
# custer 3 have 7 stocks : ['CBG', 'ESSO', 'KKP', 'KTC', 'ORI', 'SCC', 'STPI']
# custer 4 have 4 stocks : ['CK', 'GUNKUL', 'INTUCH', 'RATCH']
# custer 5 have 7 stocks : ['BEM', 'COM7', 'GFPT', 'KTB', 'PTT', 'TASCO', 'TU']
# custer 6 have 4 stocks : ['BANPU', 'BCP', 'QH', 'VGI']
# custer 7 have 8 stocks : ['AMATA', 'BJC', 'EA', 'PLANB', 'PSL', 'PTG', 'SAWAD', 'SCB']
# custer 8 have 4 stocks : ['THAI', 'TISCO', 'TRUE', 'TTW']
# custer 9 have 4 stocks : ['AEONTS', 'GPSC', 'HANA', 'TKN']
# custer 10 have 3 stocks : ['AOT', 'CPF', 'WHA']
# custer 11 have 3 stocks : ['BDMS', 'BTS', 'TMB']
# custer 12 have 3 stocks : ['HMPRO', 'LH', 'MAJOR']
# custer 13 have 3 stocks : ['CKP', 'JAS', 'THANI']
# custer 14 have 5 stocks : ['AP', 'CPN', 'JMT', 'MTC', 'SPALI']
# custer 15 have 5 stocks : ['ADVANC', 'BCH', 'KBANK', 'MEGA', 'PTTEP']
# custer 16 have 6 stocks : ['CENTEL', 'EPG', 'MBK', 'PTTGC', 'RS', 'STA']
# custer 17 have 3 stocks : ['CPALL', 'STEC', 'SUPER']
# custer 18 have 4 stocks : ['DTAC', 'IVL', 'SPRC', 'TCAP']
# custer 19 have 3 stocks : ['GLOBAL', 'IRPC', 'MINT']
# --------------------------------------------------
# score method: calinski_harabasz_score, score: 8.992466994806191
# custer 1 have 33 stocks : ['AEONTS', 'AMATA', 'AOT', 'BANPU', 'BCP', 'BDMS', 'BTS', 'CK', 'CPALL', 'CPF', 'GPSC', 'GUNKUL', 'HANA', 'HMPRO', 'INTUCH', 'JAS', 'LH', 'MAJOR', 'MINT', 'QH', 'RATCH', 'STEC', 'SUPER', 'TCAP', 'THAI', 'THANI', 'TISCO', 'TKN', 'TMB', 'TRUE', 'TTW', 'VGI', 'WHA']
# custer 2 have 35 stocks : ['BBL', 'BCH', 'BEC', 'BEM', 'BH', 'BJC', 'CBG', 'COM7', 'DELTA', 'DTAC', 'EA', 'ESSO', 'GFPT', 'IVL', 'KBANK', 'KCE', 'KKP', 'KTB', 'KTC', 'MEGA', 'ORI', 'PLANB', 'PSL', 'PTG', 'PTT', 'PTTEP', 'SAWAD', 'SCB', 'SCC', 'SGP', 'SPRC', 'STA', 'STPI', 'TASCO', 'TU']
# custer 3 have 18 stocks : ['ADVANC', 'AP', 'CENTEL', 'CHG', 'CKP', 'CPN', 'EGCO', 'EPG', 'ERW', 'GLOBAL', 'IRPC', 'JMT', 'MBK', 'MTC', 'PTTGC', 'RS', 'SPALI', 'TOP']
#
#
# ==================================================
# calinski_harabasz_score
# --------------------------------------------------
# score method: silhouette_score, score: 0.1583507141462027
# custer 1 have 4 stocks : ['ERW', 'MEGA', 'PTG', 'RS']
# custer 2 have 3 stocks : ['CHG', 'KTB', 'SUPER']
# custer 3 have 8 stocks : ['BANPU', 'BEM', 'BJC', 'HMPRO', 'IVL', 'QH', 'SPALI', 'VGI']
# custer 4 have 6 stocks : ['BEC', 'DELTA', 'KBANK', 'PTT', 'PTTEP', 'TASCO']
# custer 5 have 9 stocks : ['BDMS', 'CPALL', 'EA', 'EGCO', 'HANA', 'MBK', 'PLANB', 'RATCH', 'TOP']
# custer 6 have 5 stocks : ['CK', 'CPF', 'INTUCH', 'MAJOR', 'MINT']
# custer 7 have 9 stocks : ['AEONTS', 'AMATA', 'COM7', 'CPN', 'KTC', 'ORI', 'PTTGC', 'SAWAD', 'TU']
# custer 8 have 5 stocks : ['GLOBAL', 'IRPC', 'TISCO', 'TMB', 'TRUE']
# custer 9 have 3 stocks : ['GPSC', 'JMT', 'STEC']
# custer 10 have 2 stocks : ['CKP', 'EPG']
# custer 11 have 2 stocks : ['MTC', 'TCAP']
# custer 12 have 3 stocks : ['BTS', 'LH', 'TTW']
# custer 13 have 8 stocks : ['AOT', 'AP', 'BBL', 'BCH', 'CENTEL', 'GFPT', 'SCC', 'THAI']
# custer 14 have 10 stocks : ['ADVANC', 'BH', 'CBG', 'DTAC', 'KCE', 'KKP', 'SCB', 'SGP', 'STPI', 'TKN']
# custer 15 have 3 stocks : ['ESSO', 'PSL', 'STA']
# custer 16 have 3 stocks : ['BCP', 'JAS', 'SPRC']
# custer 17 have 3 stocks : ['GUNKUL', 'THANI', 'WHA']
# --------------------------------------------------
# score method: davies_bouldin_score, score: 1.2901333668687178
# custer 1 have 1 stocks : ['GPSC']
# custer 2 have 12 stocks : ['ADVANC', 'AMATA', 'BH', 'CBG', 'DTAC', 'KCE', 'KKP', 'PTTGC', 'SCB', 'SGP', 'STPI', 'TKN']
# custer 3 have 7 stocks : ['CPALL', 'EGCO', 'ESSO', 'GUNKUL', 'HANA', 'PLANB', 'STA']
# custer 4 have 4 stocks : ['CK', 'CPF', 'INTUCH', 'MINT']
# custer 5 have 8 stocks : ['BANPU', 'BEM', 'BJC', 'HMPRO', 'IVL', 'QH', 'SPALI', 'VGI']
# custer 6 have 4 stocks : ['AEONTS', 'EA', 'MBK', 'RATCH']
# custer 7 have 12 stocks : ['BEC', 'DELTA', 'ERW', 'KBANK', 'MEGA', 'PSL', 'PTG', 'PTT', 'PTTEP', 'RS', 'TASCO', 'TOP']
# custer 8 have 2 stocks : ['TISCO', 'TMB']
# custer 9 have 6 stocks : ['BCP', 'CHG', 'JAS', 'KTB', 'SPRC', 'SUPER']
# custer 10 have 3 stocks : ['JMT', 'STEC', 'THANI']
# custer 11 have 2 stocks : ['AOT', 'GFPT']
# custer 12 have 4 stocks : ['AP', 'MTC', 'SCC', 'TCAP']
# custer 13 have 3 stocks : ['BDMS', 'GLOBAL', 'WHA']
# custer 14 have 6 stocks : ['COM7', 'CPN', 'KTC', 'ORI', 'SAWAD', 'TU']
# custer 15 have 3 stocks : ['CKP', 'IRPC', 'TRUE']
# custer 16 have 3 stocks : ['BBL', 'BCH', 'CENTEL']
# custer 17 have 3 stocks : ['BTS', 'LH', 'TTW']
# custer 18 have 3 stocks : ['EPG', 'MAJOR', 'THAI']
# --------------------------------------------------
# score method: calinski_harabasz_score, score: 21.849953893408557
# custer 1 have 33 stocks : ['ADVANC', 'AMATA', 'AOT', 'BEC', 'BH', 'CBG', 'CENTEL', 'COM7', 'CPN', 'DELTA', 'DTAC', 'EA', 'ESSO', 'HANA', 'KBANK', 'KCE', 'KKP', 'KTC', 'ORI', 'PLANB', 'PSL', 'PTG', 'PTT', 'PTTEP', 'PTTGC', 'RS', 'SAWAD', 'SCB', 'SGP', 'STA', 'STPI', 'TASCO', 'TKN']
# custer 2 have 21 stocks : ['BCP', 'BTS', 'CHG', 'CK', 'CKP', 'CPF', 'HMPRO', 'INTUCH', 'IRPC', 'JAS', 'KTB', 'LH', 'MAJOR', 'MINT', 'RATCH', 'SPRC', 'SUPER', 'TISCO', 'TMB', 'TRUE', 'TTW']
# custer 3 have 32 stocks : ['AEONTS', 'AP', 'BANPU', 'BBL', 'BCH', 'BDMS', 'BEM', 'BJC', 'CPALL', 'EGCO', 'EPG', 'ERW', 'GFPT', 'GLOBAL', 'GPSC', 'GUNKUL', 'IVL', 'JMT', 'MBK', 'MEGA', 'MTC', 'QH', 'SCC', 'SPALI', 'STEC', 'TCAP', 'THAI', 'THANI', 'TOP', 'TU', 'VGI', 'WHA']
